# %% [markdown]
# ## Université de Bordeaux,  Master Mention Informatique
#
# ## Intelligence Artificielle
#
# ### Deep Learning, feuille 1

# %% [markdown]
# ### Présentation
#
# Le but de ce premier TD est de vous familiariser avec les réseaux de neurones et leur entraînement. Nous allons passer en revue les éléments de base suivant :
#
#  - données d'apprentissage,
#
#  - fonction de perte (loss function)
#
#  - descente de gradient
#
#  Pour cela, nous allons utiliser un réseau de neurone (composé d'un seul neurone en fait) pour deux tâches :
#
#   - une régression linéaire simple
#
#   - une régression logistique.

# %% [markdown]
# Commençons par importer quelques unes des bibliothèques usuelles :

# %%
import numpy as np
import random as rd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### On génère les données
#
# Afin de réaliser une régression linéaire simple, nous allongs générer un nuage de points. Exécutez le code de la cellule suivante :

# %%
#Data: 
def generate(m, sizeNoise, slope, intersect):    
    x = [rd.random()*50 + 5 for i in range(m)]
    noise = [rd.random() * sizeNoise for i in range(m)]#np.rand(m,1) * sizeNoise
    y = [intersect + slope*x[i] + noise[i] for i in range(m)] 
    return np.array([x]), np.array([y])

m = 100
sizeNoise = 10
a = 0.8
b =  20
    
X, Y = generate(m, sizeNoise, a, b)
plt.grid()
plt.scatter(X, Y)

# %% [markdown]
# ### Exercice 1. Un neurone :
#
# Comme vu en cours, un neurone formel est représenté comme suit :
#
# ![Un neurone formel (Mc Culloch & Pitts (1943))](img/formal_neuron_s.png)
#
# 1. Nommez chacun des élements du neurone.
#
# 2. Ecrivez une fonction <code>neuron(x, w, b, f)</code> permettant d'implémenter ce neurone

# %%
def neuron(x, w, b, f):
    weighted_sum = np.dot(w, x) + b
    output = f(weighted_sum)
    return output

# %% [markdown]
# Dans un réseau de neurones, il y a différentes couches ("layers") : une couche d'entrée où l'on passe les paramètres d'entrée, la couche de sortie qui affiche le résultat, et les couches cachées qui effectuent des opérations sur les données. Chaque couche est composée de nœuds qui ont un poids ("weight"). Les différentes couches sont connectées de telle sorte que chaque neurone de la couche n-1 est relié à chaque neurone de la couche n. Chaque neurone possède également un biais.
# le neurones s'active en fonction de la fonction d'activation, l'erreur entre le label et le le poid du neurone et calculer par une fonction cout.

# %% [markdown]
# 3. Définissez deux fonctions <code>id</code> et <code>sigmoid</code> définies par :
# $$
# id(z) = z \mbox{ et } sigmoid(z) = \frac{1}{1+ e^{-z}}.
# $$

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def id(x):
    return x

# %% [markdown]
# 4. Testez vos fonctions. L'exécution de la cellule suivante devrait donner le résultat affiché.

# %%
x = np.array([[1, 2, 3]])
y = np.array([1, 0, 1])

w = np.array([1])
b = [1]
y_hat = neuron(x, w, b, id)
print('x: ', x)
print('y_hat: ', y_hat)
# Out:
# x:  [[1 2 3]]
# y_hat:  [2 3 4]

# %% [markdown]
# ### Exercice 2. Régression linéaire :
#
# Dans cet exercice, nous allons entraîner un neurone pour réaliser une régression linéaire simple.
#
# 1. Dessiner le neurone qui sera utilisé. Identifiez bien les paramètres à trouver.

# %% [markdown]
# Il suffit de prendre $p=1$ et $f=id$ dans le neurone formel de la figure ci-dessus.
#
# Les paramètres à trouver sont $w$ et $b$. Ils correspondent respectivement à $\beta_1$ et $\beta_0$ dans l'expression de la régression linéaire simple (voir votre cours de ACID).

# %% [markdown]
# 1. Ecrivez le code de la fonction <code>loss(y, y_hat)</code> définie comme la moyenne des carrés des écarts :
#
# $$
# loss\left(y, \hat{y}\right) = \frac 1 {n} \sum_{i=1}^n \left(\hat{y_i} - y_i)\right)^2.
# $$

# %%
def loss(y, y_hat):
    return np.mean((y_hat - y)**2)

# %% [markdown]
# 2. Calculez le gradient de la fonction ${\cal L} = loss$ par rapport aux deux variables $w$ et $b$.

# %%
print(loss(y,y_hat))
# Out:
# 6.333333333333333

# %% [markdown]
# 3. Ecrivez la focntion <code>gradient(x, y_hat, y)</code> retournant le gradient de la fonction $\cal L$.

# %%
def gradient(x, y_hat, y):
    n = len(y)
    
    # Calcul du gradient par rapport à w
    gradient_w = (2/n) * np.sum((y_hat - y) * x, axis=0)
    
    # Calcul du gradient par rapport à b
    gradient_b = (2/n) * np.sum(y_hat - y)
    
    return gradient_w, gradient_b

# %% [markdown]
# 4. Ecrivez une fonction <code>train(x, y, nu, epochs)</code> qui réalise une déscente du gradient de la fonction $\cal L$ afin de trouver les paramètres $w$ et $b$ minimisant la valeur de $\cal L$.

# %%
def train(x, y, nu, epochs):
    # Initialisation des poids
    w = np.zeros(x.shape[1])
    b = 0.0
    
    n = len(y)
    
    # Entraînement sur plusieurs époques
    for epoch in range(epochs):
        total_loss = 0
        
        y_pred = neurons(x, w, b, id)  # Utilisez id ou sigmoid comme fonction d'activation
        total_loss += loss(y,y_pred)
            
        gradient_w ,gradient_b = gradient(x,y_pred,y)
            
        w = w - nu * gradient_w
        b = b - nu * gradient_b
        
        # Calcul de la perte moyenne pour l'époque
        mean_loss = total_loss / n
        print(f'Époque {epoch + 1}/{epochs}, Perte moyenne: {mean_loss}')
    
    # Retourne les poids entraînés
    return w, b

# %% [markdown]
# 5. Entraînez votre neurone. Prenez $0.001$ comme valeur pour le pas d'apprentissage, et 10000 pour le nombre d'epochs.

# %%
import numpy as np

# Paramètres d'entraînement
learning_rate = 0.001
num_epochs = 10000

# Entraînement du neurone
trained_w, trained_b = train(X, Y, learning_rate, num_epochs)
# Out:
# Époque 1/10000, Perte moyenne: 2788.631950769632
# Époque 2/10000, Perte moyenne: 227119876.24999914
# Époque 3/10000, Perte moyenne: 14572932954756.443
# Époque 4/10000, Perte moyenne: 9.360694180316768e+17
# Époque 5/10000, Perte moyenne: 6.012668992004324e+22
# Époque 6/10000, Perte moyenne: 3.862126923382088e+27
# Époque 7/10000, Perte moyenne: 2.4807659279362462e+32
# Époque 8/10000, Perte moyenne: 1.5934741947376826e+37
# Époque 9/10000, Perte moyenne: 1.0235387308012713e+42
# Époque 10/10000, Perte moyenne: 6.574512074999362e+46
# Époque 11/10000, Perte moyenne: 4.2230164549293226e+51
# Époque 12/10000, Perte moyenne: 2.7125766559042396e+56
# Époque 13/10000, Perte moyenne: 1.7423735362356696e+61
# Époque 14/10000, Perte moyenne: 1.1191814738825827e+66
# Époque 15/10000, Perte moyenne: 7.188855577938312e+70
# Époque 16/10000, Perte moyenne: 4.6176286622375485e+75
# Époque 17/10000, Perte moyenne: 2.9660485220698786e+80
# Époque 18/10000, Perte moyenne: 1.905186509954216e+85
# Époque 19/10000, Perte moyenne: 1.2237613817519376e+90
# Époque 20/10000, Perte moyenne: 7.860605308943744e+94
# Époque 21/10000, Perte moyenne: 5.049114700329671e+99
# Époque 22/10000, Perte moyenne: 3.243205612687202e+104
# Époque 23/10000, Perte moyenne: 2.083213250330599e+109
# Époque 24/10000, Perte moyenne: 1.3381135717624743e+114
# Époque 25/10000, Perte moyenne: 8.595125490156955e+118
# Époque 26/10000, Perte moyenne: 5.520920178265668e+123
# Époque 27/10000, Perte moyenne: 3.5462611511242055e+128
# Époque 28/10000, Perte moyenne: 2.277875380535455e+133
# Époque 29/10000, Perte moyenne: 1.463151197312319e+138
# Époque 30/10000, Perte moyenne: 9.398281593847488e+142
# Époque 31/10000, Perte moyenne: 6.036812673871487e+147
# Époque 32/10000, Perte moyenne: 3.8776351714416243e+152
# Époque 33/10000, Perte moyenne: 2.4907273647698386e+157
# Époque 34/10000, Perte moyenne: 1.599872739783021e+162
# Époque 35/10000, Perte moyenne: 1.0276487180833422e+167
# Époque 36/10000, Perte moyenne: 6.600911819533617e+171
# Époque 37/10000, Perte moyenne: 4.239973843447628e+176
# Époque 38/10000, Perte moyenne: 2.723468921357329e+181
# Époque 39/10000, Perte moyenne: 1.7493699818600955e+186
# Époque 40/10000, Perte moyenne: 1.1236755115633896e+191
# Époque 41/10000, Perte moyenne: 7.217722199306751e+195
# Époque 42/10000, Perte moyenne: 4.636170603547643e+200
# Époque 43/10000, Perte moyenne: 2.977958595755288e+205
# Époque 44/10000, Perte moyenne: 1.9128367259062363e+210
# Époque 45/10000, Perte moyenne: 1.2286753567329858e+215
# Époque 46/10000, Perte moyenne: 7.892169320032853e+219
# Époque 47/10000, Perte moyenne: 5.069389260128526e+224
# Époque 48/10000, Perte moyenne: 3.2562286018718446e+229
# Époque 49/10000, Perte moyenne: 2.0915783270072764e+234
# Époque 50/10000, Perte moyenne: 1.3434867243324863e+239
# Époque 51/10000, Perte moyenne: 8.629638943716945e+243
# Époque 52/10000, Perte moyenne: 5.543089257984069e+248
# Époque 53/10000, Perte moyenne: 3.560501050203176e+253
# Époque 54/10000, Perte moyenne: 2.2870221168165713e+258
# Époque 55/10000, Perte moyenne: 1.4690264344985017e+263
# Époque 56/10000, Perte moyenne: 9.436020095246268e+267
# Époque 57/10000, Perte moyenne: 6.061053303529384e+272
# Époque 58/10000, Perte moyenne: 3.893205692379962e+277
# Époque 59/10000, Perte moyenne: 2.5007288014368216e+282
# Époque 60/10000, Perte moyenne: 1.6062969779828724e+287
# Époque 61/10000, Perte moyenne: 1.0317752088888772e+292
# Époque 62/10000, Perte moyenne: 6.627417571404013e+296
# Époque 63/10000, Perte moyenne: 4.2569993238212393e+301
# Époque 64/10000, Perte moyenne: inf
# Époque 65/10000, Perte moyenne: inf
# Époque 66/10000, Perte moyenne: inf
# Époque 67/10000, Perte moyenne: inf
# Époque 68/10000, Perte moyenne: inf
# Époque 69/10000, Perte moyenne: inf
# Époque 70/10000, Perte moyenne: inf
# Époque 71/10000, Perte moyenne: inf
# Époque 72/10000, Perte moyenne: inf
# Époque 73/10000, Perte moyenne: inf
# Époque 74/10000, Perte moyenne: inf
# Époque 75/10000, Perte moyenne: inf
# Époque 76/10000, Perte moyenne: inf
# Époque 77/10000, Perte moyenne: inf
# Époque 78/10000, Perte moyenne: inf
# Époque 79/10000, Perte moyenne: inf
# Époque 80/10000, Perte moyenne: inf
# Époque 81/10000, Perte moyenne: inf
# Époque 82/10000, Perte moyenne: inf
# Époque 83/10000, Perte moyenne: inf
# Époque 84/10000, Perte moyenne: inf
# Époque 85/10000, Perte moyenne: inf
# Époque 86/10000, Perte moyenne: inf
# Époque 87/10000, Perte moyenne: inf
# Époque 88/10000, Perte moyenne: inf
# Époque 89/10000, Perte moyenne: inf
# Époque 90/10000, Perte moyenne: inf
# Époque 91/10000, Perte moyenne: inf
# Époque 92/10000, Perte moyenne: inf
# Époque 93/10000, Perte moyenne: inf
# Époque 94/10000, Perte moyenne: inf
# Époque 95/10000, Perte moyenne: inf
# Époque 96/10000, Perte moyenne: inf
# Époque 97/10000, Perte moyenne: inf
# Époque 98/10000, Perte moyenne: inf
# Époque 99/10000, Perte moyenne: inf
# Époque 100/10000, Perte moyenne: inf
# Époque 101/10000, Perte moyenne: inf
# Époque 102/10000, Perte moyenne: inf
# Époque 103/10000, Perte moyenne: inf
# Époque 104/10000, Perte moyenne: inf
# Époque 105/10000, Perte moyenne: inf
# Époque 106/10000, Perte moyenne: inf
# Époque 107/10000, Perte moyenne: inf
# Époque 108/10000, Perte moyenne: inf
# Époque 109/10000, Perte moyenne: inf
# Époque 110/10000, Perte moyenne: inf
# Époque 111/10000, Perte moyenne: inf
# Époque 112/10000, Perte moyenne: inf
# Époque 113/10000, Perte moyenne: inf
# Époque 114/10000, Perte moyenne: inf
# Époque 115/10000, Perte moyenne: inf
# Époque 116/10000, Perte moyenne: inf
# Époque 117/10000, Perte moyenne: inf
# Époque 118/10000, Perte moyenne: inf
# Époque 119/10000, Perte moyenne: inf
# Époque 120/10000, Perte moyenne: inf
# Époque 121/10000, Perte moyenne: inf
# Époque 122/10000, Perte moyenne: inf
# Époque 123/10000, Perte moyenne: inf
# Époque 124/10000, Perte moyenne: inf
# Époque 125/10000, Perte moyenne: inf
# Époque 126/10000, Perte moyenne: inf
# Époque 127/10000, Perte moyenne: inf
# Époque 128/10000, Perte moyenne: inf
# Époque 129/10000, Perte moyenne: inf
# Époque 130/10000, Perte moyenne: nan
# Époque 131/10000, Perte moyenne: nan
# Époque 132/10000, Perte moyenne: nan
# Époque 133/10000, Perte moyenne: nan
# Époque 134/10000, Perte moyenne: nan
# Époque 135/10000, Perte moyenne: nan
# Époque 136/10000, Perte moyenne: nan
# Époque 137/10000, Perte moyenne: nan
# Époque 138/10000, Perte moyenne: nan
# Époque 139/10000, Perte moyenne: nan
# Époque 140/10000, Perte moyenne: nan
# Époque 141/10000, Perte moyenne: nan
# Époque 142/10000, Perte moyenne: nan
# Époque 143/10000, Perte moyenne: nan
# Époque 144/10000, Perte moyenne: nan
# Époque 145/10000, Perte moyenne: nan
# Époque 146/10000, Perte moyenne: nan
# Époque 147/10000, Perte moyenne: nan
# Époque 148/10000, Perte moyenne: nan
# Époque 149/10000, Perte moyenne: nan
# Époque 150/10000, Perte moyenne: nan
# Époque 151/10000, Perte moyenne: nan
# Époque 152/10000, Perte moyenne: nan
# Époque 153/10000, Perte moyenne: nan
# Époque 154/10000, Perte moyenne: nan
# Époque 155/10000, Perte moyenne: nan
# Époque 156/10000, Perte moyenne: nan
# Époque 157/10000, Perte moyenne: nan
# Époque 158/10000, Perte moyenne: nan
# Époque 159/10000, Perte moyenne: nan
# Époque 160/10000, Perte moyenne: nan
# Époque 161/10000, Perte moyenne: nan
# Époque 162/10000, Perte moyenne: nan
# Époque 163/10000, Perte moyenne: nan
# Époque 164/10000, Perte moyenne: nan
# Époque 165/10000, Perte moyenne: nan
# Époque 166/10000, Perte moyenne: nan
# Époque 167/10000, Perte moyenne: nan
# Époque 168/10000, Perte moyenne: nan
# Époque 169/10000, Perte moyenne: nan
# Époque 170/10000, Perte moyenne: nan
# Époque 171/10000, Perte moyenne: nan
# Époque 172/10000, Perte moyenne: nan
# Époque 173/10000, Perte moyenne: nan
# Époque 174/10000, Perte moyenne: nan
# Époque 175/10000, Perte moyenne: nan
# Époque 176/10000, Perte moyenne: nan
# Époque 177/10000, Perte moyenne: nan
# Époque 178/10000, Perte moyenne: nan
# Époque 179/10000, Perte moyenne: nan
# Époque 180/10000, Perte moyenne: nan
# Époque 181/10000, Perte moyenne: nan
# Époque 182/10000, Perte moyenne: nan
# Époque 183/10000, Perte moyenne: nan
# Époque 184/10000, Perte moyenne: nan
# Époque 185/10000, Perte moyenne: nan
# Époque 186/10000, Perte moyenne: nan
# Époque 187/10000, Perte moyenne: nan
# Époque 188/10000, Perte moyenne: nan
# Époque 189/10000, Perte moyenne: nan
# Époque 190/10000, Perte moyenne: nan
# Époque 191/10000, Perte moyenne: nan
# Époque 192/10000, Perte moyenne: nan
# Époque 193/10000, Perte moyenne: nan
# Époque 194/10000, Perte moyenne: nan
# Époque 195/10000, Perte moyenne: nan
# Époque 196/10000, Perte moyenne: nan
# Époque 197/10000, Perte moyenne: nan
# Époque 198/10000, Perte moyenne: nan
# Époque 199/10000, Perte moyenne: nan
# Époque 200/10000, Perte moyenne: nan
# Époque 201/10000, Perte moyenne: nan
# Époque 202/10000, Perte moyenne: nan
# Époque 203/10000, Perte moyenne: nan
# Époque 204/10000, Perte moyenne: nan
# Époque 205/10000, Perte moyenne: nan
# Époque 206/10000, Perte moyenne: nan
# Époque 207/10000, Perte moyenne: nan
# Époque 208/10000, Perte moyenne: nan
# Époque 209/10000, Perte moyenne: nan
# Époque 210/10000, Perte moyenne: nan
# Époque 211/10000, Perte moyenne: nan
# Époque 212/10000, Perte moyenne: nan
# Époque 213/10000, Perte moyenne: nan
# Époque 214/10000, Perte moyenne: nan
# Époque 215/10000, Perte moyenne: nan
# Époque 216/10000, Perte moyenne: nan
# Époque 217/10000, Perte moyenne: nan
# Époque 218/10000, Perte moyenne: nan
# Époque 219/10000, Perte moyenne: nan
# Époque 220/10000, Perte moyenne: nan
# Époque 221/10000, Perte moyenne: nan
# Époque 222/10000, Perte moyenne: nan
# Époque 223/10000, Perte moyenne: nan
# Époque 224/10000, Perte moyenne: nan
# Époque 225/10000, Perte moyenne: nan
# Époque 226/10000, Perte moyenne: nan
# Époque 227/10000, Perte moyenne: nan
# Époque 228/10000, Perte moyenne: nan
# Époque 229/10000, Perte moyenne: nan
# Époque 230/10000, Perte moyenne: nan
# Époque 231/10000, Perte moyenne: nan
# Époque 232/10000, Perte moyenne: nan
# Époque 233/10000, Perte moyenne: nan
# Époque 234/10000, Perte moyenne: nan
# Époque 235/10000, Perte moyenne: nan
# Époque 236/10000, Perte moyenne: nan
# Époque 237/10000, Perte moyenne: nan
# Époque 238/10000, Perte moyenne: nan
# Époque 239/10000, Perte moyenne: nan
# Époque 240/10000, Perte moyenne: nan
# Époque 241/10000, Perte moyenne: nan
# Époque 242/10000, Perte moyenne: nan
# Époque 243/10000, Perte moyenne: nan
# Époque 244/10000, Perte moyenne: nan
# Époque 245/10000, Perte moyenne: nan
# Époque 246/10000, Perte moyenne: nan
# Époque 247/10000, Perte moyenne: nan
# Époque 248/10000, Perte moyenne: nan
# Époque 249/10000, Perte moyenne: nan
# Époque 250/10000, Perte moyenne: nan
# Époque 251/10000, Perte moyenne: nan
# Époque 252/10000, Perte moyenne: nan
# Époque 253/10000, Perte moyenne: nan
# Époque 254/10000, Perte moyenne: nan
# Époque 255/10000, Perte moyenne: nan
# Époque 256/10000, Perte moyenne: nan
# Époque 257/10000, Perte moyenne: nan
# Époque 258/10000, Perte moyenne: nan
# Époque 259/10000, Perte moyenne: nan
# Époque 260/10000, Perte moyenne: nan
# Époque 261/10000, Perte moyenne: nan
# Époque 262/10000, Perte moyenne: nan
# Époque 263/10000, Perte moyenne: nan
# Époque 264/10000, Perte moyenne: nan
# Époque 265/10000, Perte moyenne: nan
# Époque 266/10000, Perte moyenne: nan
# Époque 267/10000, Perte moyenne: nan
# Époque 268/10000, Perte moyenne: nan
# Époque 269/10000, Perte moyenne: nan
# Époque 270/10000, Perte moyenne: nan
# Époque 271/10000, Perte moyenne: nan
# Époque 272/10000, Perte moyenne: nan
# Époque 273/10000, Perte moyenne: nan
# Époque 274/10000, Perte moyenne: nan
# Époque 275/10000, Perte moyenne: nan
# Époque 276/10000, Perte moyenne: nan
# Époque 277/10000, Perte moyenne: nan
# Époque 278/10000, Perte moyenne: nan
# Époque 279/10000, Perte moyenne: nan
# Époque 280/10000, Perte moyenne: nan
# Époque 281/10000, Perte moyenne: nan
# Époque 282/10000, Perte moyenne: nan
# Époque 283/10000, Perte moyenne: nan
# Époque 284/10000, Perte moyenne: nan
# Époque 285/10000, Perte moyenne: nan
# Époque 286/10000, Perte moyenne: nan
# Époque 287/10000, Perte moyenne: nan
# Époque 288/10000, Perte moyenne: nan
# Époque 289/10000, Perte moyenne: nan
# Époque 290/10000, Perte moyenne: nan
# Époque 291/10000, Perte moyenne: nan
# Époque 292/10000, Perte moyenne: nan
# Époque 293/10000, Perte moyenne: nan
# Époque 294/10000, Perte moyenne: nan
# Époque 295/10000, Perte moyenne: nan
# Époque 296/10000, Perte moyenne: nan
# Époque 297/10000, Perte moyenne: nan
# Époque 298/10000, Perte moyenne: nan
# Époque 299/10000, Perte moyenne: nan
# Époque 300/10000, Perte moyenne: nan
# Époque 301/10000, Perte moyenne: nan
# Époque 302/10000, Perte moyenne: nan
# Époque 303/10000, Perte moyenne: nan
# Époque 304/10000, Perte moyenne: nan
# Époque 305/10000, Perte moyenne: nan
# Époque 306/10000, Perte moyenne: nan
# Époque 307/10000, Perte moyenne: nan
# Époque 308/10000, Perte moyenne: nan
# Époque 309/10000, Perte moyenne: nan
# Époque 310/10000, Perte moyenne: nan
# Époque 311/10000, Perte moyenne: nan
# Époque 312/10000, Perte moyenne: nan
# Époque 313/10000, Perte moyenne: nan
# Époque 314/10000, Perte moyenne: nan
# Époque 315/10000, Perte moyenne: nan
# Époque 316/10000, Perte moyenne: nan
# Époque 317/10000, Perte moyenne: nan
# Époque 318/10000, Perte moyenne: nan
# Époque 319/10000, Perte moyenne: nan
# Époque 320/10000, Perte moyenne: nan
# Époque 321/10000, Perte moyenne: nan
# Époque 322/10000, Perte moyenne: nan
# Époque 323/10000, Perte moyenne: nan
# Époque 324/10000, Perte moyenne: nan
# Époque 325/10000, Perte moyenne: nan
# Époque 326/10000, Perte moyenne: nan
# Époque 327/10000, Perte moyenne: nan
# Époque 328/10000, Perte moyenne: nan
# Époque 329/10000, Perte moyenne: nan
# Époque 330/10000, Perte moyenne: nan
# Époque 331/10000, Perte moyenne: nan
# Époque 332/10000, Perte moyenne: nan
# Époque 333/10000, Perte moyenne: nan
# Époque 334/10000, Perte moyenne: nan
# Époque 335/10000, Perte moyenne: nan
# Époque 336/10000, Perte moyenne: nan
# Époque 337/10000, Perte moyenne: nan
# Époque 338/10000, Perte moyenne: nan
# Époque 339/10000, Perte moyenne: nan
# Époque 340/10000, Perte moyenne: nan
# Époque 341/10000, Perte moyenne: nan
# Époque 342/10000, Perte moyenne: nan
# Époque 343/10000, Perte moyenne: nan
# Époque 344/10000, Perte moyenne: nan
# Époque 345/10000, Perte moyenne: nan
# Époque 346/10000, Perte moyenne: nan
# Époque 347/10000, Perte moyenne: nan
# Époque 348/10000, Perte moyenne: nan
# Époque 349/10000, Perte moyenne: nan
# Époque 350/10000, Perte moyenne: nan
# Époque 351/10000, Perte moyenne: nan
# Époque 352/10000, Perte moyenne: nan
# Époque 353/10000, Perte moyenne: nan
# Époque 354/10000, Perte moyenne: nan
# Époque 355/10000, Perte moyenne: nan
# Époque 356/10000, Perte moyenne: nan
# Époque 357/10000, Perte moyenne: nan
# Époque 358/10000, Perte moyenne: nan
# Époque 359/10000, Perte moyenne: nan
# Époque 360/10000, Perte moyenne: nan
# Époque 361/10000, Perte moyenne: nan
# Époque 362/10000, Perte moyenne: nan
# Époque 363/10000, Perte moyenne: nan
# Époque 364/10000, Perte moyenne: nan
# Époque 365/10000, Perte moyenne: nan
# Époque 366/10000, Perte moyenne: nan
# Époque 367/10000, Perte moyenne: nan
# Époque 368/10000, Perte moyenne: nan
# Époque 369/10000, Perte moyenne: nan
# Époque 370/10000, Perte moyenne: nan
# Époque 371/10000, Perte moyenne: nan
# Époque 372/10000, Perte moyenne: nan
# Époque 373/10000, Perte moyenne: nan
# Époque 374/10000, Perte moyenne: nan
# Époque 375/10000, Perte moyenne: nan
# Époque 376/10000, Perte moyenne: nan
# Époque 377/10000, Perte moyenne: nan
# Époque 378/10000, Perte moyenne: nan
# Époque 379/10000, Perte moyenne: nan
# Époque 380/10000, Perte moyenne: nan
# Époque 381/10000, Perte moyenne: nan
# Époque 382/10000, Perte moyenne: nan
# Époque 383/10000, Perte moyenne: nan
# Époque 384/10000, Perte moyenne: nan
# Époque 385/10000, Perte moyenne: nan
# Époque 386/10000, Perte moyenne: nan
# Époque 387/10000, Perte moyenne: nan
# Époque 388/10000, Perte moyenne: nan
# Époque 389/10000, Perte moyenne: nan
# Époque 390/10000, Perte moyenne: nan
# Époque 391/10000, Perte moyenne: nan
# Époque 392/10000, Perte moyenne: nan
# Époque 393/10000, Perte moyenne: nan
# Époque 394/10000, Perte moyenne: nan
# Époque 395/10000, Perte moyenne: nan
# Époque 396/10000, Perte moyenne: nan
# Époque 397/10000, Perte moyenne: nan
# Époque 398/10000, Perte moyenne: nan
# Époque 399/10000, Perte moyenne: nan
# Époque 400/10000, Perte moyenne: nan
# Époque 401/10000, Perte moyenne: nan
# Époque 402/10000, Perte moyenne: nan
# Époque 403/10000, Perte moyenne: nan
# Époque 404/10000, Perte moyenne: nan
# Époque 405/10000, Perte moyenne: nan
# Époque 406/10000, Perte moyenne: nan
# Époque 407/10000, Perte moyenne: nan
# Époque 408/10000, Perte moyenne: nan
# Époque 409/10000, Perte moyenne: nan
# Époque 410/10000, Perte moyenne: nan
# Époque 411/10000, Perte moyenne: nan
# Époque 412/10000, Perte moyenne: nan
# Époque 413/10000, Perte moyenne: nan
# Époque 414/10000, Perte moyenne: nan
# Époque 415/10000, Perte moyenne: nan
# Époque 416/10000, Perte moyenne: nan
# Époque 417/10000, Perte moyenne: nan
# Époque 418/10000, Perte moyenne: nan
# Époque 419/10000, Perte moyenne: nan
# Époque 420/10000, Perte moyenne: nan
# Époque 421/10000, Perte moyenne: nan
# Époque 422/10000, Perte moyenne: nan
# Époque 423/10000, Perte moyenne: nan
# Époque 424/10000, Perte moyenne: nan
# Époque 425/10000, Perte moyenne: nan
# Époque 426/10000, Perte moyenne: nan
# Époque 427/10000, Perte moyenne: nan
# Époque 428/10000, Perte moyenne: nan
# Époque 429/10000, Perte moyenne: nan
# Époque 430/10000, Perte moyenne: nan
# Époque 431/10000, Perte moyenne: nan
# Époque 432/10000, Perte moyenne: nan
# Époque 433/10000, Perte moyenne: nan
# Époque 434/10000, Perte moyenne: nan
# Époque 435/10000, Perte moyenne: nan
# Époque 436/10000, Perte moyenne: nan
# Époque 437/10000, Perte moyenne: nan
# Époque 438/10000, Perte moyenne: nan
# Époque 439/10000, Perte moyenne: nan
# Époque 440/10000, Perte moyenne: nan
# Époque 441/10000, Perte moyenne: nan
# Époque 442/10000, Perte moyenne: nan
# Époque 443/10000, Perte moyenne: nan
# Époque 444/10000, Perte moyenne: nan
# Époque 445/10000, Perte moyenne: nan
# Époque 446/10000, Perte moyenne: nan
# Époque 447/10000, Perte moyenne: nan
# Époque 448/10000, Perte moyenne: nan
# Époque 449/10000, Perte moyenne: nan
# Époque 450/10000, Perte moyenne: nan
# Époque 451/10000, Perte moyenne: nan
# Époque 452/10000, Perte moyenne: nan
# Époque 453/10000, Perte moyenne: nan
# Époque 454/10000, Perte moyenne: nan
# Époque 455/10000, Perte moyenne: nan
# Époque 456/10000, Perte moyenne: nan
# Époque 457/10000, Perte moyenne: nan
# Époque 458/10000, Perte moyenne: nan
# Époque 459/10000, Perte moyenne: nan
# Époque 460/10000, Perte moyenne: nan
# Époque 461/10000, Perte moyenne: nan
# Époque 462/10000, Perte moyenne: nan
# Époque 463/10000, Perte moyenne: nan
# Époque 464/10000, Perte moyenne: nan
# Époque 465/10000, Perte moyenne: nan
# Époque 466/10000, Perte moyenne: nan
# Époque 467/10000, Perte moyenne: nan
# Époque 468/10000, Perte moyenne: nan
# Époque 469/10000, Perte moyenne: nan
# Époque 470/10000, Perte moyenne: nan
# Époque 471/10000, Perte moyenne: nan
# Époque 472/10000, Perte moyenne: nan
# Époque 473/10000, Perte moyenne: nan
# Époque 474/10000, Perte moyenne: nan
# Époque 475/10000, Perte moyenne: nan
# Époque 476/10000, Perte moyenne: nan
# Époque 477/10000, Perte moyenne: nan
# Époque 478/10000, Perte moyenne: nan
# Époque 479/10000, Perte moyenne: nan
# Époque 480/10000, Perte moyenne: nan
# Époque 481/10000, Perte moyenne: nan
# Époque 482/10000, Perte moyenne: nan
# Époque 483/10000, Perte moyenne: nan
# Époque 484/10000, Perte moyenne: nan
# Époque 485/10000, Perte moyenne: nan
# Époque 486/10000, Perte moyenne: nan
# Époque 487/10000, Perte moyenne: nan
# Époque 488/10000, Perte moyenne: nan
# Époque 489/10000, Perte moyenne: nan
# Époque 490/10000, Perte moyenne: nan
# Époque 491/10000, Perte moyenne: nan
# Époque 492/10000, Perte moyenne: nan
# Époque 493/10000, Perte moyenne: nan
# Époque 494/10000, Perte moyenne: nan
# Époque 495/10000, Perte moyenne: nan
# Époque 496/10000, Perte moyenne: nan
# Époque 497/10000, Perte moyenne: nan
# Époque 498/10000, Perte moyenne: nan
# Époque 499/10000, Perte moyenne: nan
# Époque 500/10000, Perte moyenne: nan
# Époque 501/10000, Perte moyenne: nan
# Époque 502/10000, Perte moyenne: nan
# Époque 503/10000, Perte moyenne: nan
# Époque 504/10000, Perte moyenne: nan
# Époque 505/10000, Perte moyenne: nan
# Époque 506/10000, Perte moyenne: nan
# Époque 507/10000, Perte moyenne: nan
# Époque 508/10000, Perte moyenne: nan
# Époque 509/10000, Perte moyenne: nan
# Époque 510/10000, Perte moyenne: nan
# Époque 511/10000, Perte moyenne: nan
# Époque 512/10000, Perte moyenne: nan
# Époque 513/10000, Perte moyenne: nan
# Époque 514/10000, Perte moyenne: nan
# Époque 515/10000, Perte moyenne: nan
# Époque 516/10000, Perte moyenne: nan
# Époque 517/10000, Perte moyenne: nan
# Époque 518/10000, Perte moyenne: nan
# Époque 519/10000, Perte moyenne: nan
# Époque 520/10000, Perte moyenne: nan
# Époque 521/10000, Perte moyenne: nan
# Époque 522/10000, Perte moyenne: nan
# Époque 523/10000, Perte moyenne: nan
# Époque 524/10000, Perte moyenne: nan
# Époque 525/10000, Perte moyenne: nan
# Époque 526/10000, Perte moyenne: nan
# Époque 527/10000, Perte moyenne: nan
# Époque 528/10000, Perte moyenne: nan
# Époque 529/10000, Perte moyenne: nan
# Époque 530/10000, Perte moyenne: nan
# Époque 531/10000, Perte moyenne: nan
# Époque 532/10000, Perte moyenne: nan
# Époque 533/10000, Perte moyenne: nan
# Époque 534/10000, Perte moyenne: nan
# Époque 535/10000, Perte moyenne: nan
# Époque 536/10000, Perte moyenne: nan
# Époque 537/10000, Perte moyenne: nan
# Époque 538/10000, Perte moyenne: nan
# Époque 539/10000, Perte moyenne: nan
# Époque 540/10000, Perte moyenne: nan
# Époque 541/10000, Perte moyenne: nan
# Époque 542/10000, Perte moyenne: nan
# Époque 543/10000, Perte moyenne: nan
# Époque 544/10000, Perte moyenne: nan
# Époque 545/10000, Perte moyenne: nan
# Époque 546/10000, Perte moyenne: nan
# Époque 547/10000, Perte moyenne: nan
# Époque 548/10000, Perte moyenne: nan
# Époque 549/10000, Perte moyenne: nan
# Époque 550/10000, Perte moyenne: nan
# Époque 551/10000, Perte moyenne: nan
# Époque 552/10000, Perte moyenne: nan
# Époque 553/10000, Perte moyenne: nan
# Époque 554/10000, Perte moyenne: nan
# Époque 555/10000, Perte moyenne: nan
# Époque 556/10000, Perte moyenne: nan
# Époque 557/10000, Perte moyenne: nan
# Époque 558/10000, Perte moyenne: nan
# Époque 559/10000, Perte moyenne: nan
# Époque 560/10000, Perte moyenne: nan
# Époque 561/10000, Perte moyenne: nan
# Époque 562/10000, Perte moyenne: nan
# Époque 563/10000, Perte moyenne: nan
# Époque 564/10000, Perte moyenne: nan
# Époque 565/10000, Perte moyenne: nan
# Époque 566/10000, Perte moyenne: nan
# Époque 567/10000, Perte moyenne: nan
# Époque 568/10000, Perte moyenne: nan
# Époque 569/10000, Perte moyenne: nan
# Époque 570/10000, Perte moyenne: nan
# Époque 571/10000, Perte moyenne: nan
# Époque 572/10000, Perte moyenne: nan
# Époque 573/10000, Perte moyenne: nan
# Époque 574/10000, Perte moyenne: nan
# Époque 575/10000, Perte moyenne: nan
# Époque 576/10000, Perte moyenne: nan
# Époque 577/10000, Perte moyenne: nan
# Époque 578/10000, Perte moyenne: nan
# Époque 579/10000, Perte moyenne: nan
# Époque 580/10000, Perte moyenne: nan
# Époque 581/10000, Perte moyenne: nan
# Époque 582/10000, Perte moyenne: nan
# Époque 583/10000, Perte moyenne: nan
# Époque 584/10000, Perte moyenne: nan
# Époque 585/10000, Perte moyenne: nan
# Époque 586/10000, Perte moyenne: nan
# Époque 587/10000, Perte moyenne: nan
# Époque 588/10000, Perte moyenne: nan
# Époque 589/10000, Perte moyenne: nan
# Époque 590/10000, Perte moyenne: nan
# Époque 591/10000, Perte moyenne: nan
# Époque 592/10000, Perte moyenne: nan
# Époque 593/10000, Perte moyenne: nan
# Époque 594/10000, Perte moyenne: nan
# Époque 595/10000, Perte moyenne: nan
# Époque 596/10000, Perte moyenne: nan
# Époque 597/10000, Perte moyenne: nan
# Époque 598/10000, Perte moyenne: nan
# Époque 599/10000, Perte moyenne: nan
# Époque 600/10000, Perte moyenne: nan
# Époque 601/10000, Perte moyenne: nan
# Époque 602/10000, Perte moyenne: nan
# Époque 603/10000, Perte moyenne: nan
# Époque 604/10000, Perte moyenne: nan
# Époque 605/10000, Perte moyenne: nan
# Époque 606/10000, Perte moyenne: nan
# Époque 607/10000, Perte moyenne: nan
# Époque 608/10000, Perte moyenne: nan
# Époque 609/10000, Perte moyenne: nan
# Époque 610/10000, Perte moyenne: nan
# Époque 611/10000, Perte moyenne: nan
# Époque 612/10000, Perte moyenne: nan
# Époque 613/10000, Perte moyenne: nan
# Époque 614/10000, Perte moyenne: nan
# Époque 615/10000, Perte moyenne: nan
# Époque 616/10000, Perte moyenne: nan
# Époque 617/10000, Perte moyenne: nan
# Époque 618/10000, Perte moyenne: nan
# Époque 619/10000, Perte moyenne: nan
# Époque 620/10000, Perte moyenne: nan
# Époque 621/10000, Perte moyenne: nan
# Époque 622/10000, Perte moyenne: nan
# Époque 623/10000, Perte moyenne: nan
# Époque 624/10000, Perte moyenne: nan
# Époque 625/10000, Perte moyenne: nan
# Époque 626/10000, Perte moyenne: nan
# Époque 627/10000, Perte moyenne: nan
# Époque 628/10000, Perte moyenne: nan
# Époque 629/10000, Perte moyenne: nan
# Époque 630/10000, Perte moyenne: nan
# Époque 631/10000, Perte moyenne: nan
# Époque 632/10000, Perte moyenne: nan
# Époque 633/10000, Perte moyenne: nan
# Époque 634/10000, Perte moyenne: nan
# Époque 635/10000, Perte moyenne: nan
# Époque 636/10000, Perte moyenne: nan
# Époque 637/10000, Perte moyenne: nan
# Époque 638/10000, Perte moyenne: nan
# Époque 639/10000, Perte moyenne: nan
# Époque 640/10000, Perte moyenne: nan
# Époque 641/10000, Perte moyenne: nan
# Époque 642/10000, Perte moyenne: nan
# Époque 643/10000, Perte moyenne: nan
# Époque 644/10000, Perte moyenne: nan
# Époque 645/10000, Perte moyenne: nan
# Époque 646/10000, Perte moyenne: nan
# Époque 647/10000, Perte moyenne: nan
# Époque 648/10000, Perte moyenne: nan
# Époque 649/10000, Perte moyenne: nan
# Époque 650/10000, Perte moyenne: nan
# Époque 651/10000, Perte moyenne: nan
# Époque 652/10000, Perte moyenne: nan
# Époque 653/10000, Perte moyenne: nan
# Époque 654/10000, Perte moyenne: nan
# Époque 655/10000, Perte moyenne: nan
# Époque 656/10000, Perte moyenne: nan
# Époque 657/10000, Perte moyenne: nan
# Époque 658/10000, Perte moyenne: nan
# Époque 659/10000, Perte moyenne: nan
# Époque 660/10000, Perte moyenne: nan
# Époque 661/10000, Perte moyenne: nan
# Époque 662/10000, Perte moyenne: nan
# Époque 663/10000, Perte moyenne: nan
# Époque 664/10000, Perte moyenne: nan
# Époque 665/10000, Perte moyenne: nan
# Époque 666/10000, Perte moyenne: nan
# Époque 667/10000, Perte moyenne: nan
# Époque 668/10000, Perte moyenne: nan
# Époque 669/10000, Perte moyenne: nan
# Époque 670/10000, Perte moyenne: nan
# Époque 671/10000, Perte moyenne: nan
# Époque 672/10000, Perte moyenne: nan
# Époque 673/10000, Perte moyenne: nan
# Époque 674/10000, Perte moyenne: nan
# Époque 675/10000, Perte moyenne: nan
# Époque 676/10000, Perte moyenne: nan
# Époque 677/10000, Perte moyenne: nan
# Époque 678/10000, Perte moyenne: nan
# Époque 679/10000, Perte moyenne: nan
# Époque 680/10000, Perte moyenne: nan
# Époque 681/10000, Perte moyenne: nan
# Époque 682/10000, Perte moyenne: nan
# Époque 683/10000, Perte moyenne: nan
# Époque 684/10000, Perte moyenne: nan
# Époque 685/10000, Perte moyenne: nan
# Époque 686/10000, Perte moyenne: nan
# Époque 687/10000, Perte moyenne: nan
# Époque 688/10000, Perte moyenne: nan
# Époque 689/10000, Perte moyenne: nan
# Époque 690/10000, Perte moyenne: nan
# Époque 691/10000, Perte moyenne: nan
# Époque 692/10000, Perte moyenne: nan
# Époque 693/10000, Perte moyenne: nan
# Époque 694/10000, Perte moyenne: nan
# Époque 695/10000, Perte moyenne: nan
# Époque 696/10000, Perte moyenne: nan
# Époque 697/10000, Perte moyenne: nan
# Époque 698/10000, Perte moyenne: nan
# Époque 699/10000, Perte moyenne: nan
# Époque 700/10000, Perte moyenne: nan
# Époque 701/10000, Perte moyenne: nan
# Époque 702/10000, Perte moyenne: nan
# Époque 703/10000, Perte moyenne: nan
# Époque 704/10000, Perte moyenne: nan
# Époque 705/10000, Perte moyenne: nan
# Époque 706/10000, Perte moyenne: nan
# Époque 707/10000, Perte moyenne: nan
# Époque 708/10000, Perte moyenne: nan
# Époque 709/10000, Perte moyenne: nan
# Époque 710/10000, Perte moyenne: nan
# Époque 711/10000, Perte moyenne: nan
# Époque 712/10000, Perte moyenne: nan
# Époque 713/10000, Perte moyenne: nan
# Époque 714/10000, Perte moyenne: nan
# Époque 715/10000, Perte moyenne: nan
# Époque 716/10000, Perte moyenne: nan
# Époque 717/10000, Perte moyenne: nan
# Époque 718/10000, Perte moyenne: nan
# Époque 719/10000, Perte moyenne: nan
# Époque 720/10000, Perte moyenne: nan
# Époque 721/10000, Perte moyenne: nan
# Époque 722/10000, Perte moyenne: nan
# Époque 723/10000, Perte moyenne: nan
# Époque 724/10000, Perte moyenne: nan
# Époque 725/10000, Perte moyenne: nan
# Époque 726/10000, Perte moyenne: nan
# Époque 727/10000, Perte moyenne: nan
# Époque 728/10000, Perte moyenne: nan
# Époque 729/10000, Perte moyenne: nan
# Époque 730/10000, Perte moyenne: nan
# Époque 731/10000, Perte moyenne: nan
# Époque 732/10000, Perte moyenne: nan
# Époque 733/10000, Perte moyenne: nan
# Époque 734/10000, Perte moyenne: nan
# Époque 735/10000, Perte moyenne: nan
# Époque 736/10000, Perte moyenne: nan
# Époque 737/10000, Perte moyenne: nan
# Époque 738/10000, Perte moyenne: nan
# Époque 739/10000, Perte moyenne: nan
# Époque 740/10000, Perte moyenne: nan
# Époque 741/10000, Perte moyenne: nan
# Époque 742/10000, Perte moyenne: nan
# Époque 743/10000, Perte moyenne: nan
# Époque 744/10000, Perte moyenne: nan
# Époque 745/10000, Perte moyenne: nan
# Époque 746/10000, Perte moyenne: nan
# Époque 747/10000, Perte moyenne: nan
# Époque 748/10000, Perte moyenne: nan
# Époque 749/10000, Perte moyenne: nan
# Époque 750/10000, Perte moyenne: nan
# Époque 751/10000, Perte moyenne: nan
# Époque 752/10000, Perte moyenne: nan
# Époque 753/10000, Perte moyenne: nan
# Époque 754/10000, Perte moyenne: nan
# Époque 755/10000, Perte moyenne: nan
# Époque 756/10000, Perte moyenne: nan
# Époque 757/10000, Perte moyenne: nan
# Époque 758/10000, Perte moyenne: nan
# Époque 759/10000, Perte moyenne: nan
# Époque 760/10000, Perte moyenne: nan
# Époque 761/10000, Perte moyenne: nan
# Époque 762/10000, Perte moyenne: nan
# Époque 763/10000, Perte moyenne: nan
# Époque 764/10000, Perte moyenne: nan
# Époque 765/10000, Perte moyenne: nan
# Époque 766/10000, Perte moyenne: nan
# Époque 767/10000, Perte moyenne: nan
# Époque 768/10000, Perte moyenne: nan
# Époque 769/10000, Perte moyenne: nan
# Époque 770/10000, Perte moyenne: nan
# Époque 771/10000, Perte moyenne: nan
# Époque 772/10000, Perte moyenne: nan
# Époque 773/10000, Perte moyenne: nan
# Époque 774/10000, Perte moyenne: nan
# Époque 775/10000, Perte moyenne: nan
# Époque 776/10000, Perte moyenne: nan
# Époque 777/10000, Perte moyenne: nan
# Époque 778/10000, Perte moyenne: nan
# Époque 779/10000, Perte moyenne: nan
# Époque 780/10000, Perte moyenne: nan
# Époque 781/10000, Perte moyenne: nan
# Époque 782/10000, Perte moyenne: nan
# Époque 783/10000, Perte moyenne: nan
# Époque 784/10000, Perte moyenne: nan
# Époque 785/10000, Perte moyenne: nan
# Époque 786/10000, Perte moyenne: nan
# Époque 787/10000, Perte moyenne: nan
# Époque 788/10000, Perte moyenne: nan
# Époque 789/10000, Perte moyenne: nan
# Époque 790/10000, Perte moyenne: nan
# Époque 791/10000, Perte moyenne: nan
# Époque 792/10000, Perte moyenne: nan
# Époque 793/10000, Perte moyenne: nan
# Époque 794/10000, Perte moyenne: nan
# Époque 795/10000, Perte moyenne: nan
# Époque 796/10000, Perte moyenne: nan
# Époque 797/10000, Perte moyenne: nan
# Époque 798/10000, Perte moyenne: nan
# Époque 799/10000, Perte moyenne: nan
# Époque 800/10000, Perte moyenne: nan
# Époque 801/10000, Perte moyenne: nan
# Époque 802/10000, Perte moyenne: nan
# Époque 803/10000, Perte moyenne: nan
# Époque 804/10000, Perte moyenne: nan
# Époque 805/10000, Perte moyenne: nan
# Époque 806/10000, Perte moyenne: nan
# Époque 807/10000, Perte moyenne: nan
# Époque 808/10000, Perte moyenne: nan
# Époque 809/10000, Perte moyenne: nan
# Époque 810/10000, Perte moyenne: nan
# Époque 811/10000, Perte moyenne: nan
# Époque 812/10000, Perte moyenne: nan
# Époque 813/10000, Perte moyenne: nan
# Époque 814/10000, Perte moyenne: nan
# Époque 815/10000, Perte moyenne: nan
# Époque 816/10000, Perte moyenne: nan
# Époque 817/10000, Perte moyenne: nan
# Époque 818/10000, Perte moyenne: nan
# Époque 819/10000, Perte moyenne: nan
# Époque 820/10000, Perte moyenne: nan
# Époque 821/10000, Perte moyenne: nan
# Époque 822/10000, Perte moyenne: nan
# Époque 823/10000, Perte moyenne: nan
# Époque 824/10000, Perte moyenne: nan
# Époque 825/10000, Perte moyenne: nan
# Époque 826/10000, Perte moyenne: nan
# Époque 827/10000, Perte moyenne: nan
# Époque 828/10000, Perte moyenne: nan
# Époque 829/10000, Perte moyenne: nan
# Époque 830/10000, Perte moyenne: nan
# Époque 831/10000, Perte moyenne: nan
# Époque 832/10000, Perte moyenne: nan
# Époque 833/10000, Perte moyenne: nan
# Époque 834/10000, Perte moyenne: nan
# Époque 835/10000, Perte moyenne: nan
# Époque 836/10000, Perte moyenne: nan
# Époque 837/10000, Perte moyenne: nan
# Époque 838/10000, Perte moyenne: nan
# Époque 839/10000, Perte moyenne: nan
# Époque 840/10000, Perte moyenne: nan
# Époque 841/10000, Perte moyenne: nan
# Époque 842/10000, Perte moyenne: nan
# Époque 843/10000, Perte moyenne: nan
# Époque 844/10000, Perte moyenne: nan
# Époque 845/10000, Perte moyenne: nan
# Époque 846/10000, Perte moyenne: nan
# Époque 847/10000, Perte moyenne: nan
# Époque 848/10000, Perte moyenne: nan
# Époque 849/10000, Perte moyenne: nan
# Époque 850/10000, Perte moyenne: nan
# Époque 851/10000, Perte moyenne: nan
# Époque 852/10000, Perte moyenne: nan
# Époque 853/10000, Perte moyenne: nan
# Époque 854/10000, Perte moyenne: nan
# Époque 855/10000, Perte moyenne: nan
# Époque 856/10000, Perte moyenne: nan
# Époque 857/10000, Perte moyenne: nan
# Époque 858/10000, Perte moyenne: nan
# Époque 859/10000, Perte moyenne: nan
# Époque 860/10000, Perte moyenne: nan
# Époque 861/10000, Perte moyenne: nan
# Époque 862/10000, Perte moyenne: nan
# Époque 863/10000, Perte moyenne: nan
# Époque 864/10000, Perte moyenne: nan
# Époque 865/10000, Perte moyenne: nan
# Époque 866/10000, Perte moyenne: nan
# Époque 867/10000, Perte moyenne: nan
# Époque 868/10000, Perte moyenne: nan
# Époque 869/10000, Perte moyenne: nan
# Époque 870/10000, Perte moyenne: nan
# Époque 871/10000, Perte moyenne: nan
# Époque 872/10000, Perte moyenne: nan
# Époque 873/10000, Perte moyenne: nan
# Époque 874/10000, Perte moyenne: nan
# Époque 875/10000, Perte moyenne: nan
# Époque 876/10000, Perte moyenne: nan
# Époque 877/10000, Perte moyenne: nan
# Époque 878/10000, Perte moyenne: nan
# Époque 879/10000, Perte moyenne: nan
# Époque 880/10000, Perte moyenne: nan
# Époque 881/10000, Perte moyenne: nan
# Époque 882/10000, Perte moyenne: nan
# Époque 883/10000, Perte moyenne: nan
# Époque 884/10000, Perte moyenne: nan
# Époque 885/10000, Perte moyenne: nan
# Époque 886/10000, Perte moyenne: nan
# Époque 887/10000, Perte moyenne: nan
# Époque 888/10000, Perte moyenne: nan
# Époque 889/10000, Perte moyenne: nan
# Époque 890/10000, Perte moyenne: nan
# Époque 891/10000, Perte moyenne: nan
# Époque 892/10000, Perte moyenne: nan
# Époque 893/10000, Perte moyenne: nan
# Époque 894/10000, Perte moyenne: nan
# Époque 895/10000, Perte moyenne: nan
# Époque 896/10000, Perte moyenne: nan
# Époque 897/10000, Perte moyenne: nan
# Époque 898/10000, Perte moyenne: nan
# Époque 899/10000, Perte moyenne: nan
# Époque 900/10000, Perte moyenne: nan
# Époque 901/10000, Perte moyenne: nan
# Époque 902/10000, Perte moyenne: nan
# Époque 903/10000, Perte moyenne: nan
# Époque 904/10000, Perte moyenne: nan
# Époque 905/10000, Perte moyenne: nan
# Époque 906/10000, Perte moyenne: nan
# Époque 907/10000, Perte moyenne: nan
# Époque 908/10000, Perte moyenne: nan
# Époque 909/10000, Perte moyenne: nan
# Époque 910/10000, Perte moyenne: nan
# Époque 911/10000, Perte moyenne: nan
# Époque 912/10000, Perte moyenne: nan
# Époque 913/10000, Perte moyenne: nan
# Époque 914/10000, Perte moyenne: nan
# Époque 915/10000, Perte moyenne: nan
# Époque 916/10000, Perte moyenne: nan
# Époque 917/10000, Perte moyenne: nan
# Époque 918/10000, Perte moyenne: nan
# Époque 919/10000, Perte moyenne: nan
# Époque 920/10000, Perte moyenne: nan
# Époque 921/10000, Perte moyenne: nan
# Époque 922/10000, Perte moyenne: nan
# Époque 923/10000, Perte moyenne: nan
# Époque 924/10000, Perte moyenne: nan
# Époque 925/10000, Perte moyenne: nan
# Époque 926/10000, Perte moyenne: nan
# Époque 927/10000, Perte moyenne: nan
# Époque 928/10000, Perte moyenne: nan
# Époque 929/10000, Perte moyenne: nan
# Époque 930/10000, Perte moyenne: nan
# Époque 931/10000, Perte moyenne: nan
# Époque 932/10000, Perte moyenne: nan
# Époque 933/10000, Perte moyenne: nan
# Époque 934/10000, Perte moyenne: nan
# Époque 935/10000, Perte moyenne: nan
# Époque 936/10000, Perte moyenne: nan
# Époque 937/10000, Perte moyenne: nan
# Époque 938/10000, Perte moyenne: nan
# Époque 939/10000, Perte moyenne: nan
# Époque 940/10000, Perte moyenne: nan
# Époque 941/10000, Perte moyenne: nan
# Époque 942/10000, Perte moyenne: nan
# Époque 943/10000, Perte moyenne: nan
# Époque 944/10000, Perte moyenne: nan
# Époque 945/10000, Perte moyenne: nan
# Époque 946/10000, Perte moyenne: nan
# Époque 947/10000, Perte moyenne: nan
# Époque 948/10000, Perte moyenne: nan
# Époque 949/10000, Perte moyenne: nan
# Époque 950/10000, Perte moyenne: nan
# Époque 951/10000, Perte moyenne: nan
# Époque 952/10000, Perte moyenne: nan
# Époque 953/10000, Perte moyenne: nan
# Époque 954/10000, Perte moyenne: nan
# Époque 955/10000, Perte moyenne: nan
# Époque 956/10000, Perte moyenne: nan
# Époque 957/10000, Perte moyenne: nan
# Époque 958/10000, Perte moyenne: nan
# Époque 959/10000, Perte moyenne: nan
# Époque 960/10000, Perte moyenne: nan
# Époque 961/10000, Perte moyenne: nan
# Époque 962/10000, Perte moyenne: nan
# Époque 963/10000, Perte moyenne: nan
# Époque 964/10000, Perte moyenne: nan
# Époque 965/10000, Perte moyenne: nan
# Époque 966/10000, Perte moyenne: nan
# Époque 967/10000, Perte moyenne: nan
# Époque 968/10000, Perte moyenne: nan
# Époque 969/10000, Perte moyenne: nan
# Époque 970/10000, Perte moyenne: nan
# Époque 971/10000, Perte moyenne: nan
# Époque 972/10000, Perte moyenne: nan
# Époque 973/10000, Perte moyenne: nan
# Époque 974/10000, Perte moyenne: nan
# Époque 975/10000, Perte moyenne: nan
# Époque 976/10000, Perte moyenne: nan
# Époque 977/10000, Perte moyenne: nan
# Époque 978/10000, Perte moyenne: nan
# Époque 979/10000, Perte moyenne: nan
# Époque 980/10000, Perte moyenne: nan
# Époque 981/10000, Perte moyenne: nan
# Époque 982/10000, Perte moyenne: nan
# Époque 983/10000, Perte moyenne: nan
# Époque 984/10000, Perte moyenne: nan
# Époque 985/10000, Perte moyenne: nan
# Époque 986/10000, Perte moyenne: nan
# Époque 987/10000, Perte moyenne: nan
# Époque 988/10000, Perte moyenne: nan
# Époque 989/10000, Perte moyenne: nan
# Époque 990/10000, Perte moyenne: nan
# Époque 991/10000, Perte moyenne: nan
# Époque 992/10000, Perte moyenne: nan
# Époque 993/10000, Perte moyenne: nan
# Époque 994/10000, Perte moyenne: nan
# Époque 995/10000, Perte moyenne: nan
# Époque 996/10000, Perte moyenne: nan
# Époque 997/10000, Perte moyenne: nan
# Époque 998/10000, Perte moyenne: nan
# Époque 999/10000, Perte moyenne: nan
# Époque 1000/10000, Perte moyenne: nan
# Époque 1001/10000, Perte moyenne: nan
# Époque 1002/10000, Perte moyenne: nan
# Époque 1003/10000, Perte moyenne: nan
# Époque 1004/10000, Perte moyenne: nan
# Époque 1005/10000, Perte moyenne: nan
# Époque 1006/10000, Perte moyenne: nan
# Époque 1007/10000, Perte moyenne: nan
# Époque 1008/10000, Perte moyenne: nan
# Époque 1009/10000, Perte moyenne: nan
# Époque 1010/10000, Perte moyenne: nan
# Époque 1011/10000, Perte moyenne: nan
# Époque 1012/10000, Perte moyenne: nan
# Époque 1013/10000, Perte moyenne: nan
# Époque 1014/10000, Perte moyenne: nan
# Époque 1015/10000, Perte moyenne: nan
# Époque 1016/10000, Perte moyenne: nan
# Époque 1017/10000, Perte moyenne: nan
# Époque 1018/10000, Perte moyenne: nan
# Époque 1019/10000, Perte moyenne: nan
# Époque 1020/10000, Perte moyenne: nan
# Époque 1021/10000, Perte moyenne: nan
# Époque 1022/10000, Perte moyenne: nan
# Époque 1023/10000, Perte moyenne: nan
# Époque 1024/10000, Perte moyenne: nan
# Époque 1025/10000, Perte moyenne: nan
# Époque 1026/10000, Perte moyenne: nan
# Époque 1027/10000, Perte moyenne: nan
# Époque 1028/10000, Perte moyenne: nan
# Époque 1029/10000, Perte moyenne: nan
# Époque 1030/10000, Perte moyenne: nan
# Époque 1031/10000, Perte moyenne: nan
# Époque 1032/10000, Perte moyenne: nan
# Époque 1033/10000, Perte moyenne: nan
# Époque 1034/10000, Perte moyenne: nan
# Époque 1035/10000, Perte moyenne: nan
# Époque 1036/10000, Perte moyenne: nan
# Époque 1037/10000, Perte moyenne: nan
# Époque 1038/10000, Perte moyenne: nan
# Époque 1039/10000, Perte moyenne: nan
# Époque 1040/10000, Perte moyenne: nan
# Époque 1041/10000, Perte moyenne: nan
# Époque 1042/10000, Perte moyenne: nan
# Époque 1043/10000, Perte moyenne: nan
# Époque 1044/10000, Perte moyenne: nan
# Époque 1045/10000, Perte moyenne: nan
# Époque 1046/10000, Perte moyenne: nan
# Époque 1047/10000, Perte moyenne: nan
# Époque 1048/10000, Perte moyenne: nan
# Époque 1049/10000, Perte moyenne: nan
# Époque 1050/10000, Perte moyenne: nan
# Époque 1051/10000, Perte moyenne: nan
# Époque 1052/10000, Perte moyenne: nan
# Époque 1053/10000, Perte moyenne: nan
# Époque 1054/10000, Perte moyenne: nan
# Époque 1055/10000, Perte moyenne: nan
# Époque 1056/10000, Perte moyenne: nan
# Époque 1057/10000, Perte moyenne: nan
# Époque 1058/10000, Perte moyenne: nan
# Époque 1059/10000, Perte moyenne: nan
# Époque 1060/10000, Perte moyenne: nan
# Époque 1061/10000, Perte moyenne: nan
# Époque 1062/10000, Perte moyenne: nan
# Époque 1063/10000, Perte moyenne: nan
# Époque 1064/10000, Perte moyenne: nan
# Époque 1065/10000, Perte moyenne: nan
# Époque 1066/10000, Perte moyenne: nan
# Époque 1067/10000, Perte moyenne: nan
# Époque 1068/10000, Perte moyenne: nan
# Époque 1069/10000, Perte moyenne: nan
# Époque 1070/10000, Perte moyenne: nan
# Époque 1071/10000, Perte moyenne: nan
# Époque 1072/10000, Perte moyenne: nan
# Époque 1073/10000, Perte moyenne: nan
# Époque 1074/10000, Perte moyenne: nan
# Époque 1075/10000, Perte moyenne: nan
# Époque 1076/10000, Perte moyenne: nan
# Époque 1077/10000, Perte moyenne: nan
# Époque 1078/10000, Perte moyenne: nan
# Époque 1079/10000, Perte moyenne: nan
# Époque 1080/10000, Perte moyenne: nan
# Époque 1081/10000, Perte moyenne: nan
# Époque 1082/10000, Perte moyenne: nan
# Époque 1083/10000, Perte moyenne: nan
# Époque 1084/10000, Perte moyenne: nan
# Époque 1085/10000, Perte moyenne: nan
# Époque 1086/10000, Perte moyenne: nan
# Époque 1087/10000, Perte moyenne: nan
# Époque 1088/10000, Perte moyenne: nan
# Époque 1089/10000, Perte moyenne: nan
# Époque 1090/10000, Perte moyenne: nan
# Époque 1091/10000, Perte moyenne: nan
# Époque 1092/10000, Perte moyenne: nan
# Époque 1093/10000, Perte moyenne: nan
# Époque 1094/10000, Perte moyenne: nan
# Époque 1095/10000, Perte moyenne: nan
# Époque 1096/10000, Perte moyenne: nan
# Époque 1097/10000, Perte moyenne: nan
# Époque 1098/10000, Perte moyenne: nan
# Époque 1099/10000, Perte moyenne: nan
# Époque 1100/10000, Perte moyenne: nan
# Époque 1101/10000, Perte moyenne: nan
# Époque 1102/10000, Perte moyenne: nan
# Époque 1103/10000, Perte moyenne: nan
# Époque 1104/10000, Perte moyenne: nan
# Époque 1105/10000, Perte moyenne: nan
# Époque 1106/10000, Perte moyenne: nan
# Époque 1107/10000, Perte moyenne: nan
# Époque 1108/10000, Perte moyenne: nan
# Époque 1109/10000, Perte moyenne: nan
# Époque 1110/10000, Perte moyenne: nan
# Époque 1111/10000, Perte moyenne: nan
# Époque 1112/10000, Perte moyenne: nan
# Époque 1113/10000, Perte moyenne: nan
# Époque 1114/10000, Perte moyenne: nan
# Époque 1115/10000, Perte moyenne: nan
# Époque 1116/10000, Perte moyenne: nan
# Époque 1117/10000, Perte moyenne: nan
# Époque 1118/10000, Perte moyenne: nan
# Époque 1119/10000, Perte moyenne: nan
# Époque 1120/10000, Perte moyenne: nan
# Époque 1121/10000, Perte moyenne: nan
# Époque 1122/10000, Perte moyenne: nan
# Époque 1123/10000, Perte moyenne: nan
# Époque 1124/10000, Perte moyenne: nan
# Époque 1125/10000, Perte moyenne: nan
# Époque 1126/10000, Perte moyenne: nan
# Époque 1127/10000, Perte moyenne: nan
# Époque 1128/10000, Perte moyenne: nan
# Époque 1129/10000, Perte moyenne: nan
# Époque 1130/10000, Perte moyenne: nan
# Époque 1131/10000, Perte moyenne: nan
# Époque 1132/10000, Perte moyenne: nan
# Époque 1133/10000, Perte moyenne: nan
# Époque 1134/10000, Perte moyenne: nan
# Époque 1135/10000, Perte moyenne: nan
# Époque 1136/10000, Perte moyenne: nan
# Époque 1137/10000, Perte moyenne: nan
# Époque 1138/10000, Perte moyenne: nan
# Époque 1139/10000, Perte moyenne: nan
# Époque 1140/10000, Perte moyenne: nan
# Époque 1141/10000, Perte moyenne: nan
# Époque 1142/10000, Perte moyenne: nan
# Époque 1143/10000, Perte moyenne: nan
# Époque 1144/10000, Perte moyenne: nan
# Époque 1145/10000, Perte moyenne: nan
# Époque 1146/10000, Perte moyenne: nan
# Époque 1147/10000, Perte moyenne: nan
# Époque 1148/10000, Perte moyenne: nan
# Époque 1149/10000, Perte moyenne: nan
# Époque 1150/10000, Perte moyenne: nan
# Époque 1151/10000, Perte moyenne: nan
# Époque 1152/10000, Perte moyenne: nan
# Époque 1153/10000, Perte moyenne: nan
# Époque 1154/10000, Perte moyenne: nan
# Époque 1155/10000, Perte moyenne: nan
# Époque 1156/10000, Perte moyenne: nan
# Époque 1157/10000, Perte moyenne: nan
# Époque 1158/10000, Perte moyenne: nan
# Époque 1159/10000, Perte moyenne: nan
# Époque 1160/10000, Perte moyenne: nan
# Époque 1161/10000, Perte moyenne: nan
# Époque 1162/10000, Perte moyenne: nan
# Époque 1163/10000, Perte moyenne: nan
# Époque 1164/10000, Perte moyenne: nan
# Époque 1165/10000, Perte moyenne: nan
# Époque 1166/10000, Perte moyenne: nan
# Époque 1167/10000, Perte moyenne: nan
# Époque 1168/10000, Perte moyenne: nan
# Époque 1169/10000, Perte moyenne: nan
# Époque 1170/10000, Perte moyenne: nan
# Époque 1171/10000, Perte moyenne: nan
# Époque 1172/10000, Perte moyenne: nan
# Époque 1173/10000, Perte moyenne: nan
# Époque 1174/10000, Perte moyenne: nan
# Époque 1175/10000, Perte moyenne: nan
# Époque 1176/10000, Perte moyenne: nan
# Époque 1177/10000, Perte moyenne: nan
# Époque 1178/10000, Perte moyenne: nan
# Époque 1179/10000, Perte moyenne: nan
# Époque 1180/10000, Perte moyenne: nan
# Époque 1181/10000, Perte moyenne: nan
# Époque 1182/10000, Perte moyenne: nan
# Époque 1183/10000, Perte moyenne: nan
# Époque 1184/10000, Perte moyenne: nan
# Époque 1185/10000, Perte moyenne: nan
# Époque 1186/10000, Perte moyenne: nan
# Époque 1187/10000, Perte moyenne: nan
# Époque 1188/10000, Perte moyenne: nan
# Époque 1189/10000, Perte moyenne: nan
# Époque 1190/10000, Perte moyenne: nan
# Époque 1191/10000, Perte moyenne: nan
# Époque 1192/10000, Perte moyenne: nan
# Époque 1193/10000, Perte moyenne: nan
# Époque 1194/10000, Perte moyenne: nan
# Époque 1195/10000, Perte moyenne: nan
# Époque 1196/10000, Perte moyenne: nan
# Époque 1197/10000, Perte moyenne: nan
# Époque 1198/10000, Perte moyenne: nan
# Époque 1199/10000, Perte moyenne: nan
# Époque 1200/10000, Perte moyenne: nan
# Époque 1201/10000, Perte moyenne: nan
# Époque 1202/10000, Perte moyenne: nan
# Époque 1203/10000, Perte moyenne: nan
# Époque 1204/10000, Perte moyenne: nan
# Époque 1205/10000, Perte moyenne: nan
# Époque 1206/10000, Perte moyenne: nan
# Époque 1207/10000, Perte moyenne: nan
# Époque 1208/10000, Perte moyenne: nan
# Époque 1209/10000, Perte moyenne: nan
# Époque 1210/10000, Perte moyenne: nan
# Époque 1211/10000, Perte moyenne: nan
# Époque 1212/10000, Perte moyenne: nan
# Époque 1213/10000, Perte moyenne: nan
# Époque 1214/10000, Perte moyenne: nan
# Époque 1215/10000, Perte moyenne: nan
# Époque 1216/10000, Perte moyenne: nan
# Époque 1217/10000, Perte moyenne: nan
# Époque 1218/10000, Perte moyenne: nan
# Époque 1219/10000, Perte moyenne: nan
# Époque 1220/10000, Perte moyenne: nan
# Époque 1221/10000, Perte moyenne: nan
# Époque 1222/10000, Perte moyenne: nan
# Époque 1223/10000, Perte moyenne: nan
# Époque 1224/10000, Perte moyenne: nan
# Époque 1225/10000, Perte moyenne: nan
# Époque 1226/10000, Perte moyenne: nan
# Époque 1227/10000, Perte moyenne: nan
# Époque 1228/10000, Perte moyenne: nan
# Époque 1229/10000, Perte moyenne: nan
# Époque 1230/10000, Perte moyenne: nan
# Époque 1231/10000, Perte moyenne: nan
# Époque 1232/10000, Perte moyenne: nan
# Époque 1233/10000, Perte moyenne: nan
# Époque 1234/10000, Perte moyenne: nan
# Époque 1235/10000, Perte moyenne: nan
# Époque 1236/10000, Perte moyenne: nan
# Époque 1237/10000, Perte moyenne: nan
# Époque 1238/10000, Perte moyenne: nan
# Époque 1239/10000, Perte moyenne: nan
# Époque 1240/10000, Perte moyenne: nan
# Époque 1241/10000, Perte moyenne: nan
# Époque 1242/10000, Perte moyenne: nan
# Époque 1243/10000, Perte moyenne: nan
# Époque 1244/10000, Perte moyenne: nan
# Époque 1245/10000, Perte moyenne: nan
# Époque 1246/10000, Perte moyenne: nan
# Époque 1247/10000, Perte moyenne: nan
# Époque 1248/10000, Perte moyenne: nan
# Époque 1249/10000, Perte moyenne: nan
# Époque 1250/10000, Perte moyenne: nan
# Époque 1251/10000, Perte moyenne: nan
# Époque 1252/10000, Perte moyenne: nan
# Époque 1253/10000, Perte moyenne: nan
# Époque 1254/10000, Perte moyenne: nan
# Époque 1255/10000, Perte moyenne: nan
# Époque 1256/10000, Perte moyenne: nan
# Époque 1257/10000, Perte moyenne: nan
# Époque 1258/10000, Perte moyenne: nan
# Époque 1259/10000, Perte moyenne: nan
# Époque 1260/10000, Perte moyenne: nan
# ...
# Époque 9580/10000, Perte moyenne: nan
# Époque 9581/10000, Perte moyenne: nan
# Époque 9582/10000, Perte moyenne: nan
# Époque 9583/10000, Perte moyenne: nan
# Époque 9584/10000, Perte moyenne: nan
# Époque 9585/10000, Perte moyenne: nan
# Époque 9586/10000, Perte moyenne: nan
# Époque 9587/10000, Perte moyenne: nan
# Époque 9588/10000, Perte moyenne: nan
# Époque 9589/10000, Perte moyenne: nan
# Époque 9590/10000, Perte moyenne: nan
# Époque 9591/10000, Perte moyenne: nan
# Époque 9592/10000, Perte moyenne: nan
# Époque 9593/10000, Perte moyenne: nan
# Époque 9594/10000, Perte moyenne: nan
# Époque 9595/10000, Perte moyenne: nan
# Époque 9596/10000, Perte moyenne: nan
# Époque 9597/10000, Perte moyenne: nan
# Époque 9598/10000, Perte moyenne: nan
# Époque 9599/10000, Perte moyenne: nan
# Époque 9600/10000, Perte moyenne: nan
# Époque 9601/10000, Perte moyenne: nan
# Époque 9602/10000, Perte moyenne: nan
# Époque 9603/10000, Perte moyenne: nan
# Époque 9604/10000, Perte moyenne: nan
# Époque 9605/10000, Perte moyenne: nan
# Époque 9606/10000, Perte moyenne: nan
# Époque 9607/10000, Perte moyenne: nan
# Époque 9608/10000, Perte moyenne: nan
# Époque 9609/10000, Perte moyenne: nan
# Époque 9610/10000, Perte moyenne: nan
# Époque 9611/10000, Perte moyenne: nan
# Époque 9612/10000, Perte moyenne: nan
# Époque 9613/10000, Perte moyenne: nan
# Époque 9614/10000, Perte moyenne: nan
# Époque 9615/10000, Perte moyenne: nan
# Époque 9616/10000, Perte moyenne: nan
# Époque 9617/10000, Perte moyenne: nan
# Époque 9618/10000, Perte moyenne: nan
# Époque 9619/10000, Perte moyenne: nan
# Époque 9620/10000, Perte moyenne: nan
# Époque 9621/10000, Perte moyenne: nan
# Époque 9622/10000, Perte moyenne: nan
# Époque 9623/10000, Perte moyenne: nan
# Époque 9624/10000, Perte moyenne: nan
# Époque 9625/10000, Perte moyenne: nan
# Époque 9626/10000, Perte moyenne: nan
# Époque 9627/10000, Perte moyenne: nan
# Époque 9628/10000, Perte moyenne: nan
# Époque 9629/10000, Perte moyenne: nan
# Époque 9630/10000, Perte moyenne: nan
# Époque 9631/10000, Perte moyenne: nan
# Époque 9632/10000, Perte moyenne: nan
# Époque 9633/10000, Perte moyenne: nan
# Époque 9634/10000, Perte moyenne: nan
# Époque 9635/10000, Perte moyenne: nan
# Époque 9636/10000, Perte moyenne: nan
# Époque 9637/10000, Perte moyenne: nan
# Époque 9638/10000, Perte moyenne: nan
# Époque 9639/10000, Perte moyenne: nan
# Époque 9640/10000, Perte moyenne: nan
# Époque 9641/10000, Perte moyenne: nan
# Époque 9642/10000, Perte moyenne: nan
# Époque 9643/10000, Perte moyenne: nan
# Époque 9644/10000, Perte moyenne: nan
# Époque 9645/10000, Perte moyenne: nan
# Époque 9646/10000, Perte moyenne: nan
# Époque 9647/10000, Perte moyenne: nan
# Époque 9648/10000, Perte moyenne: nan
# Époque 9649/10000, Perte moyenne: nan
# Époque 9650/10000, Perte moyenne: nan
# Époque 9651/10000, Perte moyenne: nan
# Époque 9652/10000, Perte moyenne: nan
# Époque 9653/10000, Perte moyenne: nan
# Époque 9654/10000, Perte moyenne: nan
# Époque 9655/10000, Perte moyenne: nan
# Époque 9656/10000, Perte moyenne: nan
# Époque 9657/10000, Perte moyenne: nan
# Époque 9658/10000, Perte moyenne: nan
# Époque 9659/10000, Perte moyenne: nan
# Époque 9660/10000, Perte moyenne: nan
# Époque 9661/10000, Perte moyenne: nan
# Époque 9662/10000, Perte moyenne: nan
# Époque 9663/10000, Perte moyenne: nan
# Époque 9664/10000, Perte moyenne: nan
# Époque 9665/10000, Perte moyenne: nan
# Époque 9666/10000, Perte moyenne: nan
# Époque 9667/10000, Perte moyenne: nan
# Époque 9668/10000, Perte moyenne: nan
# Époque 9669/10000, Perte moyenne: nan
# Époque 9670/10000, Perte moyenne: nan
# Époque 9671/10000, Perte moyenne: nan
# Époque 9672/10000, Perte moyenne: nan
# Époque 9673/10000, Perte moyenne: nan
# Époque 9674/10000, Perte moyenne: nan
# Époque 9675/10000, Perte moyenne: nan
# Époque 9676/10000, Perte moyenne: nan
# Époque 9677/10000, Perte moyenne: nan
# Époque 9678/10000, Perte moyenne: nan
# Époque 9679/10000, Perte moyenne: nan
# Époque 9680/10000, Perte moyenne: nan
# Époque 9681/10000, Perte moyenne: nan
# Époque 9682/10000, Perte moyenne: nan
# Époque 9683/10000, Perte moyenne: nan
# Époque 9684/10000, Perte moyenne: nan
# Époque 9685/10000, Perte moyenne: nan
# Époque 9686/10000, Perte moyenne: nan
# Époque 9687/10000, Perte moyenne: nan
# Époque 9688/10000, Perte moyenne: nan
# Époque 9689/10000, Perte moyenne: nan
# Époque 9690/10000, Perte moyenne: nan
# Époque 9691/10000, Perte moyenne: nan
# Époque 9692/10000, Perte moyenne: nan
# Époque 9693/10000, Perte moyenne: nan
# Époque 9694/10000, Perte moyenne: nan
# Époque 9695/10000, Perte moyenne: nan
# Époque 9696/10000, Perte moyenne: nan
# Époque 9697/10000, Perte moyenne: nan
# Époque 9698/10000, Perte moyenne: nan
# Époque 9699/10000, Perte moyenne: nan
# Époque 9700/10000, Perte moyenne: nan
# Époque 9701/10000, Perte moyenne: nan
# Époque 9702/10000, Perte moyenne: nan
# Époque 9703/10000, Perte moyenne: nan
# Époque 9704/10000, Perte moyenne: nan
# Époque 9705/10000, Perte moyenne: nan
# Époque 9706/10000, Perte moyenne: nan
# Époque 9707/10000, Perte moyenne: nan
# Époque 9708/10000, Perte moyenne: nan
# Époque 9709/10000, Perte moyenne: nan
# Époque 9710/10000, Perte moyenne: nan
# Époque 9711/10000, Perte moyenne: nan
# Époque 9712/10000, Perte moyenne: nan
# Époque 9713/10000, Perte moyenne: nan
# Époque 9714/10000, Perte moyenne: nan
# Époque 9715/10000, Perte moyenne: nan
# Époque 9716/10000, Perte moyenne: nan
# Époque 9717/10000, Perte moyenne: nan
# Époque 9718/10000, Perte moyenne: nan
# Époque 9719/10000, Perte moyenne: nan
# Époque 9720/10000, Perte moyenne: nan
# Époque 9721/10000, Perte moyenne: nan
# Époque 9722/10000, Perte moyenne: nan
# Époque 9723/10000, Perte moyenne: nan
# Époque 9724/10000, Perte moyenne: nan
# Époque 9725/10000, Perte moyenne: nan
# Époque 9726/10000, Perte moyenne: nan
# Époque 9727/10000, Perte moyenne: nan
# Époque 9728/10000, Perte moyenne: nan
# Époque 9729/10000, Perte moyenne: nan
# Époque 9730/10000, Perte moyenne: nan
# Époque 9731/10000, Perte moyenne: nan
# Époque 9732/10000, Perte moyenne: nan
# Époque 9733/10000, Perte moyenne: nan
# Époque 9734/10000, Perte moyenne: nan
# Époque 9735/10000, Perte moyenne: nan
# Époque 9736/10000, Perte moyenne: nan
# Époque 9737/10000, Perte moyenne: nan
# Époque 9738/10000, Perte moyenne: nan
# Époque 9739/10000, Perte moyenne: nan
# Époque 9740/10000, Perte moyenne: nan
# Époque 9741/10000, Perte moyenne: nan
# Époque 9742/10000, Perte moyenne: nan
# Époque 9743/10000, Perte moyenne: nan
# Époque 9744/10000, Perte moyenne: nan
# Époque 9745/10000, Perte moyenne: nan
# Époque 9746/10000, Perte moyenne: nan
# Époque 9747/10000, Perte moyenne: nan
# Époque 9748/10000, Perte moyenne: nan
# Époque 9749/10000, Perte moyenne: nan
# Époque 9750/10000, Perte moyenne: nan
# Époque 9751/10000, Perte moyenne: nan
# Époque 9752/10000, Perte moyenne: nan
# Époque 9753/10000, Perte moyenne: nan
# Époque 9754/10000, Perte moyenne: nan
# Époque 9755/10000, Perte moyenne: nan
# Époque 9756/10000, Perte moyenne: nan
# Époque 9757/10000, Perte moyenne: nan
# Époque 9758/10000, Perte moyenne: nan
# Époque 9759/10000, Perte moyenne: nan
# Époque 9760/10000, Perte moyenne: nan
# Époque 9761/10000, Perte moyenne: nan
# Époque 9762/10000, Perte moyenne: nan
# Époque 9763/10000, Perte moyenne: nan
# Époque 9764/10000, Perte moyenne: nan
# Époque 9765/10000, Perte moyenne: nan
# Époque 9766/10000, Perte moyenne: nan
# Époque 9767/10000, Perte moyenne: nan
# Époque 9768/10000, Perte moyenne: nan
# Époque 9769/10000, Perte moyenne: nan
# Époque 9770/10000, Perte moyenne: nan
# Époque 9771/10000, Perte moyenne: nan
# Époque 9772/10000, Perte moyenne: nan
# Époque 9773/10000, Perte moyenne: nan
# Époque 9774/10000, Perte moyenne: nan
# Époque 9775/10000, Perte moyenne: nan
# Époque 9776/10000, Perte moyenne: nan
# Époque 9777/10000, Perte moyenne: nan
# Époque 9778/10000, Perte moyenne: nan
# Époque 9779/10000, Perte moyenne: nan
# Époque 9780/10000, Perte moyenne: nan
# Époque 9781/10000, Perte moyenne: nan
# Époque 9782/10000, Perte moyenne: nan
# Époque 9783/10000, Perte moyenne: nan
# Époque 9784/10000, Perte moyenne: nan
# Époque 9785/10000, Perte moyenne: nan
# Époque 9786/10000, Perte moyenne: nan
# Époque 9787/10000, Perte moyenne: nan
# Époque 9788/10000, Perte moyenne: nan
# Époque 9789/10000, Perte moyenne: nan
# Époque 9790/10000, Perte moyenne: nan
# Époque 9791/10000, Perte moyenne: nan
# Époque 9792/10000, Perte moyenne: nan
# Époque 9793/10000, Perte moyenne: nan
# Époque 9794/10000, Perte moyenne: nan
# Époque 9795/10000, Perte moyenne: nan
# Époque 9796/10000, Perte moyenne: nan
# Époque 9797/10000, Perte moyenne: nan
# Époque 9798/10000, Perte moyenne: nan
# Époque 9799/10000, Perte moyenne: nan
# Époque 9800/10000, Perte moyenne: nan
# Époque 9801/10000, Perte moyenne: nan
# Époque 9802/10000, Perte moyenne: nan
# Époque 9803/10000, Perte moyenne: nan
# Époque 9804/10000, Perte moyenne: nan
# Époque 9805/10000, Perte moyenne: nan
# Époque 9806/10000, Perte moyenne: nan
# Époque 9807/10000, Perte moyenne: nan
# Époque 9808/10000, Perte moyenne: nan
# Époque 9809/10000, Perte moyenne: nan
# Époque 9810/10000, Perte moyenne: nan
# Époque 9811/10000, Perte moyenne: nan
# Époque 9812/10000, Perte moyenne: nan
# Époque 9813/10000, Perte moyenne: nan
# Époque 9814/10000, Perte moyenne: nan
# Époque 9815/10000, Perte moyenne: nan
# Époque 9816/10000, Perte moyenne: nan
# Époque 9817/10000, Perte moyenne: nan
# Époque 9818/10000, Perte moyenne: nan
# Époque 9819/10000, Perte moyenne: nan
# Époque 9820/10000, Perte moyenne: nan
# Époque 9821/10000, Perte moyenne: nan
# Époque 9822/10000, Perte moyenne: nan
# Époque 9823/10000, Perte moyenne: nan
# Époque 9824/10000, Perte moyenne: nan
# Époque 9825/10000, Perte moyenne: nan
# Époque 9826/10000, Perte moyenne: nan
# Époque 9827/10000, Perte moyenne: nan
# Époque 9828/10000, Perte moyenne: nan
# Époque 9829/10000, Perte moyenne: nan
# Époque 9830/10000, Perte moyenne: nan
# Époque 9831/10000, Perte moyenne: nan
# Époque 9832/10000, Perte moyenne: nan
# Époque 9833/10000, Perte moyenne: nan
# Époque 9834/10000, Perte moyenne: nan
# Époque 9835/10000, Perte moyenne: nan
# Époque 9836/10000, Perte moyenne: nan
# Époque 9837/10000, Perte moyenne: nan
# Époque 9838/10000, Perte moyenne: nan
# Époque 9839/10000, Perte moyenne: nan
# Époque 9840/10000, Perte moyenne: nan
# Époque 9841/10000, Perte moyenne: nan
# Époque 9842/10000, Perte moyenne: nan
# Époque 9843/10000, Perte moyenne: nan
# Époque 9844/10000, Perte moyenne: nan
# Époque 9845/10000, Perte moyenne: nan
# Époque 9846/10000, Perte moyenne: nan
# Époque 9847/10000, Perte moyenne: nan
# Époque 9848/10000, Perte moyenne: nan
# Époque 9849/10000, Perte moyenne: nan
# Époque 9850/10000, Perte moyenne: nan
# Époque 9851/10000, Perte moyenne: nan
# Époque 9852/10000, Perte moyenne: nan
# Époque 9853/10000, Perte moyenne: nan
# Époque 9854/10000, Perte moyenne: nan
# Époque 9855/10000, Perte moyenne: nan
# Époque 9856/10000, Perte moyenne: nan
# Époque 9857/10000, Perte moyenne: nan
# Époque 9858/10000, Perte moyenne: nan
# Époque 9859/10000, Perte moyenne: nan
# Époque 9860/10000, Perte moyenne: nan
# Époque 9861/10000, Perte moyenne: nan
# Époque 9862/10000, Perte moyenne: nan
# Époque 9863/10000, Perte moyenne: nan
# Époque 9864/10000, Perte moyenne: nan
# Époque 9865/10000, Perte moyenne: nan
# Époque 9866/10000, Perte moyenne: nan
# Époque 9867/10000, Perte moyenne: nan
# Époque 9868/10000, Perte moyenne: nan
# Époque 9869/10000, Perte moyenne: nan
# Époque 9870/10000, Perte moyenne: nan
# Époque 9871/10000, Perte moyenne: nan
# Époque 9872/10000, Perte moyenne: nan
# Époque 9873/10000, Perte moyenne: nan
# Époque 9874/10000, Perte moyenne: nan
# Époque 9875/10000, Perte moyenne: nan
# Époque 9876/10000, Perte moyenne: nan
# Époque 9877/10000, Perte moyenne: nan
# Époque 9878/10000, Perte moyenne: nan
# Époque 9879/10000, Perte moyenne: nan
# Époque 9880/10000, Perte moyenne: nan
# Époque 9881/10000, Perte moyenne: nan
# Époque 9882/10000, Perte moyenne: nan
# Époque 9883/10000, Perte moyenne: nan
# Époque 9884/10000, Perte moyenne: nan
# Époque 9885/10000, Perte moyenne: nan
# Époque 9886/10000, Perte moyenne: nan
# Époque 9887/10000, Perte moyenne: nan
# Époque 9888/10000, Perte moyenne: nan
# Époque 9889/10000, Perte moyenne: nan
# Époque 9890/10000, Perte moyenne: nan
# Époque 9891/10000, Perte moyenne: nan
# Époque 9892/10000, Perte moyenne: nan
# Époque 9893/10000, Perte moyenne: nan
# Époque 9894/10000, Perte moyenne: nan
# Époque 9895/10000, Perte moyenne: nan
# Époque 9896/10000, Perte moyenne: nan
# Époque 9897/10000, Perte moyenne: nan
# Époque 9898/10000, Perte moyenne: nan
# Époque 9899/10000, Perte moyenne: nan
# Époque 9900/10000, Perte moyenne: nan
# Époque 9901/10000, Perte moyenne: nan
# Époque 9902/10000, Perte moyenne: nan
# Époque 9903/10000, Perte moyenne: nan
# Époque 9904/10000, Perte moyenne: nan
# Époque 9905/10000, Perte moyenne: nan
# Époque 9906/10000, Perte moyenne: nan
# Époque 9907/10000, Perte moyenne: nan
# Époque 9908/10000, Perte moyenne: nan
# Époque 9909/10000, Perte moyenne: nan
# Époque 9910/10000, Perte moyenne: nan
# Époque 9911/10000, Perte moyenne: nan
# Époque 9912/10000, Perte moyenne: nan
# Époque 9913/10000, Perte moyenne: nan
# Époque 9914/10000, Perte moyenne: nan
# Époque 9915/10000, Perte moyenne: nan
# Époque 9916/10000, Perte moyenne: nan
# Époque 9917/10000, Perte moyenne: nan
# Époque 9918/10000, Perte moyenne: nan
# Époque 9919/10000, Perte moyenne: nan
# Époque 9920/10000, Perte moyenne: nan
# Époque 9921/10000, Perte moyenne: nan
# Époque 9922/10000, Perte moyenne: nan
# Époque 9923/10000, Perte moyenne: nan
# Époque 9924/10000, Perte moyenne: nan
# Époque 9925/10000, Perte moyenne: nan
# Époque 9926/10000, Perte moyenne: nan
# Époque 9927/10000, Perte moyenne: nan
# Époque 9928/10000, Perte moyenne: nan
# Époque 9929/10000, Perte moyenne: nan
# Époque 9930/10000, Perte moyenne: nan
# Époque 9931/10000, Perte moyenne: nan
# Époque 9932/10000, Perte moyenne: nan
# Époque 9933/10000, Perte moyenne: nan
# Époque 9934/10000, Perte moyenne: nan
# Époque 9935/10000, Perte moyenne: nan
# Époque 9936/10000, Perte moyenne: nan
# Époque 9937/10000, Perte moyenne: nan
# Époque 9938/10000, Perte moyenne: nan
# Époque 9939/10000, Perte moyenne: nan
# Époque 9940/10000, Perte moyenne: nan
# Époque 9941/10000, Perte moyenne: nan
# Époque 9942/10000, Perte moyenne: nan
# Époque 9943/10000, Perte moyenne: nan
# Époque 9944/10000, Perte moyenne: nan
# Époque 9945/10000, Perte moyenne: nan
# Époque 9946/10000, Perte moyenne: nan
# Époque 9947/10000, Perte moyenne: nan
# Époque 9948/10000, Perte moyenne: nan
# Époque 9949/10000, Perte moyenne: nan
# Époque 9950/10000, Perte moyenne: nan
# Époque 9951/10000, Perte moyenne: nan
# Époque 9952/10000, Perte moyenne: nan
# Époque 9953/10000, Perte moyenne: nan
# Époque 9954/10000, Perte moyenne: nan
# Époque 9955/10000, Perte moyenne: nan
# Époque 9956/10000, Perte moyenne: nan
# Époque 9957/10000, Perte moyenne: nan
# Époque 9958/10000, Perte moyenne: nan
# Époque 9959/10000, Perte moyenne: nan
# Époque 9960/10000, Perte moyenne: nan
# Époque 9961/10000, Perte moyenne: nan
# Époque 9962/10000, Perte moyenne: nan
# Époque 9963/10000, Perte moyenne: nan
# Époque 9964/10000, Perte moyenne: nan
# Époque 9965/10000, Perte moyenne: nan
# Époque 9966/10000, Perte moyenne: nan
# Époque 9967/10000, Perte moyenne: nan
# Époque 9968/10000, Perte moyenne: nan
# Époque 9969/10000, Perte moyenne: nan
# Époque 9970/10000, Perte moyenne: nan
# Époque 9971/10000, Perte moyenne: nan
# Époque 9972/10000, Perte moyenne: nan
# Époque 9973/10000, Perte moyenne: nan
# Époque 9974/10000, Perte moyenne: nan
# Époque 9975/10000, Perte moyenne: nan
# Époque 9976/10000, Perte moyenne: nan
# Époque 9977/10000, Perte moyenne: nan
# Époque 9978/10000, Perte moyenne: nan
# Époque 9979/10000, Perte moyenne: nan
# Époque 9980/10000, Perte moyenne: nan
# Époque 9981/10000, Perte moyenne: nan
# Époque 9982/10000, Perte moyenne: nan
# Époque 9983/10000, Perte moyenne: nan
# Époque 9984/10000, Perte moyenne: nan
# Époque 9985/10000, Perte moyenne: nan
# Époque 9986/10000, Perte moyenne: nan
# Époque 9987/10000, Perte moyenne: nan
# Époque 9988/10000, Perte moyenne: nan
# Époque 9989/10000, Perte moyenne: nan
# Époque 9990/10000, Perte moyenne: nan
# Époque 9991/10000, Perte moyenne: nan
# Époque 9992/10000, Perte moyenne: nan
# Époque 9993/10000, Perte moyenne: nan
# Époque 9994/10000, Perte moyenne: nan
# Époque 9995/10000, Perte moyenne: nan
# Époque 9996/10000, Perte moyenne: nan
# Époque 9997/10000, Perte moyenne: nan
# Époque 9998/10000, Perte moyenne: nan
# Époque 9999/10000, Perte moyenne: nan
# Époque 10000/10000, Perte moyenne: nan

# %% [markdown]
# 6. Donnez l'équation de la droite de régression obtenue. Ecrivez l'instruction permettant de calculer les valeurs prédites.

# %%
# Équation de la droite de régression
print('Équation de la droite de régression:', equation)
# Out:
# Équation de la droite de régression: y = -3.2759838199866174e+144 * x + -9.827951459959852e+144

# %% [markdown]
# 7. Dessinez la droite de régression sur la même figure que le nuage de point.

# %%
# Visualisation
plt.scatter(x_train[0], y_train, label='Données d\'entraînement')
plt.plot(x_test[0], y_pred, label='Droite de régression', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# 8. Comparez le résultat obtenu avec la droite donnée par <code>linregress</code> du sous module <code>stats</code> du module <code>scipy</code>.

# %% [markdown]
# ### Exercice 3. Régression logistique :
#
# Dans cet exercice, nous allons transformer le neurone afin de l'utiliser pour réaliser une classification. Nous allons nous limiter à une classification bianire : les élements appartiennent soit à une classe 0 soit à une classe 1.

# %% [markdown]
# 1. Comment devons-nous appeler la "fonction" <code>neuron</code> pour que le fonction d'activation soit la sigmoid ?

# %%
# Out:
# x:  [[1 2 3]]
# y_hat:  [0.88079708 0.95257413 0.98201379]

# %% [markdown]
# 2. Exécutez la cellule suivante pour générer les données, les découper en deux parties train et test, etc. Observez le résultat de la cellule.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

X, y = make_classification(n_samples=1000, n_features=1, n_classes=2, 
                           n_informative=1, n_redundant=0, n_repeated=0,
                          n_clusters_per_class=1)

X_train, X_test, y_train, y_test = train_test_split(X, y)
print(X_train.shape)
print(y_train.shape)
print(np.unique(y))
# Out:
# (750, 1)
# (750,)
# [0 1]

# %% [markdown]
# 3. Définissez la nouvelle fonction de perte. Nous allons utiliser la fonction *cross_entropy* vue en cours :
#
# $$
# \cal L = -\frac 1 n \sum_{i=1} y_i\times \log\left(\hat{y}_i\right)
# $$

# %% [markdown]
# 4. Ecrivez les expressions mathématiques de ce que calcule votre neurone.

# %% [markdown]
# 5. Calculez le gradient de $\cal L$ et écrivez la fonction correspondante

# %% [markdown]
# 6. Adaptez une fonction <code>train(x, y, nu, epochs)</code> pour réaliser une déscente du gradient de la fonction $\cal L$ afin de trouver les paramètres $w$ et $b$ minimisant la valeur de $\cal L$.

# %% [markdown]
# 7. Exécutez la cellule suivante pour que vos calculs matriciels puissent se faire et entraînez votre neurone.

# %%
X_train = np.reshape(X_train, (X_train.shape[1], X_train.shape[0]))
print(X_train.shape)
print(y_train.shape)

# %% [markdown]
# 8. Evaluez votre modèle. Pour cela :

# %% [markdown]
# 8.1. Exécutez la cellule suivante pour formater les données de test.

# %%
X_test = np.reshape(X_test, (X_test.shape[1], X_test.shape[0]))

# %% [markdown]
# 8.2. Appliquez votre neurone aux données de test et observez le résultat obtenu.

# %% [markdown]
# 8.3. Transformez les sorties en 0 et 1 :

# %% [markdown]
# 8.4. Evaluez la qualité du modèle obtenu
