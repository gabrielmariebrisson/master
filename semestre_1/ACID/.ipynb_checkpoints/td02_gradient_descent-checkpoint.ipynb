# %% [markdown]
# #### Université de Bordeaux,  Master Mention Informatique,  2021-2022
#
# # Analyse, classification et indexation des données: feuille 3
# ### Descente de gradient

# %% [markdown]
# ##### Avant de commencer :
# La méthode de la descente de gradient permet de trouver un minimum local d’une fonction de ${\mathbb R}^n$ dans ${\mathbb R}$ . L’objectif de ce TD est de comprendre cette méthode pour pouvoir l’utiliser par la suite dans différentes applications où on cherche à minimiser un critère.

# %% [markdown]
# Comme précédemment nous utilisons entre autres <code>numpy</code> pour manipuler vecteurs et matrices.

# %%
import numpy as np

# %% [markdown]
# ### Exercice 1. Polynôme :  calcul et dérivée

# %% [markdown]
# 1. Ecrivez une fonction python <code>valeurPolynome (coeff, x)</code> qui calcule la valeur du polynôme défini par le vecteur de coefficients <code>coeff</code> pour la valeur <code>x</code>. Les coefficients sont rangés dans l'ordre des puissances croissantes. Par exemple le vecteur $[1, 2, 3]$ définit le polynôme $3x^2+2x+1$. <br>Utilisez pour cela la classe <code>Polynomial</code> du module <code>numpy.polynomial</code>.

# %%
def valeurPolynome (coeff, x):
    polynome = np.polynomial.Polynomial(coeff)
    return polynome(x)
    #resultat=coeff[0]
    #for i in range (1,len(coeff)):
    #    resultat=resultat+coeff[i]*x**i
    #return resultat

# %% [markdown]
# 2. Testez cette fonction pour différentes valeurs de <code>x</code> et pour un polynôme dont vous choisirez les coefficients. Remarquez que le paramètre <code>x</code> peut lui même être un vecteur ou une matrice.

# %%
M= np.linspace(0, 10, 9)
print(M)
polynome=[1,2,3]
print("resultat polynome = ",valeurPolynome(polynome,M))
# Out:
# [ 0.    1.25  2.5   3.75  5.    6.25  7.5   8.75 10.  ]
# resultat polynome =  [  1.       8.1875  24.75    50.6875  86.     130.6875 184.75   248.1875
#  321.    ]

# %% [markdown]
# 3. La dérivée d’un polynôme est elle même un polynôme. Toujours en utilisant la classe <code>Polynomial</code>, écrivez une fonction python <code>derivPoly(coeff)</code> qui retourne le tableau de coefficients représentant la dérivée du polynôme défini par <code>coeff</code>. Testez.

# %%
def derivPoly(coeff):
    polynome = np.polynomial.Polynomial(coeff)
    derivative = polynome.deriv()
    derivative_coeff = derivative.coef
    return derivative_coeff

print("resultat dérivé polynome = ",derivPoly(polynome))
# Out:
# resultat dérivé polynome =  [2. 6.]

# %% [markdown]
# ### Exercice 2. Descente de gradient pour trouver le minimum d’une parabole

# %% [markdown]
# 1. Exécutez le script python suivant :

# %%
import numpy as np
# %matplotlib 
import matplotlib.pyplot as plt

def parabole(x):
    return x * x

x = np.linspace(-300,300,600)
y = [parabole(i) for i in x]

epsilon = 0.1
nu = 0.1

plt.plot(x,y,'g')

x0=250
xcurrent = x0 - 2*x0
xprec = x0

plt.plot(x0,parabole(x0),'ok')


while(abs(xprec - xcurrent) > epsilon):
    xprec  = xcurrent
    xcurrent = xprec - nu*2*xprec
    plt.plot(xcurrent,parabole(xcurrent),'ob')
    plt.pause(1)
    
plt.plot(xcurrent,parabole(xcurrent),'xr')
print(xcurrent)
# Out:
# Using matplotlib backend: TkAgg
# -0.3868562622766814

# %% [markdown]
# 2. Retrouvez dans le code les étapes de l’algorithme de descente du gradient en repérant bien l'utilisation de la dérivée.
# 3. Testez en modifiant l’initialisation de la position du minimum.
# 4. Comment peut-on obtenir une estimation plus précise de la position du minimum?
# 5. Testez en modifiant la variable <code>nu</code> par une autre valeur constante inférieure à 1, par exemple <code> nu = 0.6</code>.
# Que se passe-t-il si la valeur de nu est fixée à 1 ? Est-ce spécifique à la fonction choisie ?
# 6. Comparez la version suivante du script avec la précédente

# %% [markdown]
# 2. la dérivé est ici - nu*2*xprec
# 3. epsilon est la précison de la derivé
# 4. nu est le pas d'apprentissage, soit le pas de recherche du minimum ou la vitesse
#    on diminue epsilon pour aujouter de la précision
# 5. si il est a 1, alors renvoie la valeurs d'en face.
# 6.

# %%
import numpy as np
# %matplotlib
import matplotlib.pyplot as plt

def parabole(x):
    return x * x

x = np.linspace(-300,300,600)
y = [parabole(i) for i in x]

epsilon = 0.1
attenuation = 3

plt.plot(x,y,'g')

x0=250
xcurrent = x0 - 2*x0
xprec = x0

plt.plot(x0,parabole(x0),'ok')

while(abs(xprec - xcurrent) > epsilon):
    xprec  = xcurrent
    nu = 1/np.log(attenuation)
    attenuation = attenuation+1
    xcurrent = xprec - nu*2*xprec
    plt.plot(xcurrent,parabole(xcurrent),'ob')
    plt.pause(0.1)
plt.plot(xcurrent,parabole(xcurrent),'xr')
# Out:
# Using matplotlib backend: TkAgg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [37], line 27
#      25     xcurrent = xprec - nu*df(xprec)
#      26     plt.plot(xcurrent,parabole(xcurrent),'ob')
# ---> 27     plt.pause(1)
#      28 plt.plot(xcurrent,parabole(xcurrent),'xr')
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:557, in pause(interval)
#     555         canvas.draw_idle()
#     556     show(block=False)
# --> 557     canvas.start_event_loop(interval)
#     558 else:
#     559     time.sleep(interval)
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py:397, in FigureCanvasTk.start_event_loop(self, timeout)
#     394     else:
#     395         self._event_loop_id = self._tkcanvas.after_idle(
#     396             self.stop_event_loop)
# --> 397 self._tkcanvas.mainloop()
#
# File /usr/lib/python3.11/tkinter/__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# File /usr/lib/python3.11/tkinter/__init__.py:1943, in CallWrapper.__call__(self, *args)
#    1940     self.subst = subst
#    1941     self.widget = widget
# -> 1943 def __call__(self, *args):
#    1944     """Apply first function SUBST to arguments, than FUNC."""
#    1945     try:
#
# KeyboardInterrupt:

# %% [markdown]
# 7. Comment évolue la variable <code>nu</code> au fur et à mesure des itérations ? Quel est l'intérêt de procéder ainsi?

# %% [markdown]
# nu s'adpate a la courbe de la dérivé

# %% [markdown]
# ### Exercice 3. Descente de gradient pour trouver le minimum d’un polynôme

# %% [markdown]
# 1. On choisit comme exemple le polynôme $30 − 61x + 41x^2 − 11x^3 + x^4$ . Ecrivez un script python
# qui affiche ce polynôme entre 0 et 6 et qui montre les étapes de la descente de gradient à partir de la valeur initiale 5.

# %%
import numpy as np
# %matplotlib
import matplotlib.pyplot as plt

def parabole(x):
    return 30 - 61 * x + 41 * x**2 - 11 * x**3 + x**4

def df(x):
    return 61 * x + 82 * x- 33 * x**2 + 4*x**3

x = np.linspace(0,6,600)
y = [parabole(i) for i in x]

epsilon = 0.1
nu = 0.1

plt.plot(x,y,'g')

x0=5
xcurrent = x0 - nu * (4 * x0**3 - 33 * x0**2 + 82 * x0 - 61)
xprec = x0

plt.plot(x, parabole(x), 'g', label='Polynôme')
plt.plot(x0, parabole(x0), 'ok', label='Point de départ')
plt.plot(xcurrent, parabole(xcurrent), 'ob', label='Point courant')


while(abs(xprec - xcurrent) > epsilon):
    x0 = xcurrent
    xcurrent = x0 - nu * (4 * x0**3 - 33 * x0**2 + 82 * x0 - 61)
    plt.plot(xcurrent, parabole(xcurrent), 'ob')
    #plt.pause(0.01)
plt.plot(xcurrent, parabole(xcurrent), 'xr', label='Minimum trouvé')
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# 2. Changez la valeur initiale à 0.
# 3. Faites varier les paramètres de la descente de gradient (taux d'apprentissage, test d’arrêt) et commentez le
# comportement de l’algorithme.

# %% [markdown]
#     Taux d'apprentissage (eta): Si vous augmentez eta, l'algorithme peut converger plus rapidement, mais il peut aussi devenir instable ou diverger. Si vous diminuez eta, l'algorithme peut converger plus lentement mais de manière plus stable. Il est important de choisir un eta approprié en fonction de la forme de la fonction que vous optimisez.
#
#     Critère d'arrêt (epsilon): En augmentant epsilon, vous permettez à l'algorithme de s'arrêter plus tôt, même s'il n'a pas encore atteint une convergence très précise. En diminuant epsilon, l'algorithme prendra plus de temps pour converger vers une solution plus précise.
#
#     Terme de momentum (gamma): Le terme de momentum permet d'accélérer la convergence et d'éviter de rester coincé dans des minima locaux, mais un gamma trop élevé peut rendre l'algorithme instable. Vous pouvez ajuster gamma en fonction de la régularité de votre fonction.
#
#     la variable v représente la vitesse ou la vélocité de la mise à jour des paramètres. Plus précisément, v est utilisée pour accumuler l'influence des gradients précédents et pour accélérer ou ralentir le mouvement lors de la mise à jour des paramètres.

# %% [markdown]
# ### Exercice 4. Descente de gradient pour trouver le minimum d’une surface

# %% [markdown]
# 1. On choisit comme exemple la fonction définie par $f(x,y) = (x−1)(x−2)+(y+3)(y+4)$. On visualise une partie de la surface correspondante avec le code ci-dessous. Quels sont les intervalles de variation de $x$ et $y$ dans ce code? Quelles sont les coordonnées du minimum ?

# %%
import numpy as np
# %matplotlib
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

def f(x,y):
    return (x - 1) * (x - 2) + (y + 3) * (y + 4)

x = np.linspace(-8, 8, 160) 
y = np.linspace(-8, 8, 160)
x, y = np.meshgrid(x, y)

z = f(x, y)

ax = Axes3D(plt.figure())

ax.plot_surface(x, y, z) 
plt.show()

# %% [markdown]
# 2. Ecrivez une fonction python <code>animationDescenteSurface(pdep)</code> qui affiche cette surface et qui montre les étapes de la descente de gradient à partir du point initial <code>pdep</code> donné comme vecteur de deux coordonnées. Pour afficher un point 3D vous utiliserez la fonction <code>scatter</code> de <code>Axes3D</code>.

# %% [markdown]
# 3. Testez avec comme point initial <code>pdep = (1, -5)</code> puis <code>(-1, -3)</code>, <code>(-1, -5)</code> et <code>(2, -4)</code>.

# %% [markdown]
# ### Exercice 5. Application : régression linéaire
#
# On veut calculer la droite de régression linéaire correspondant à un nuage de
# points 2D $\{(x_1, y_1), \cdots , (x_m, y_m)\}$, c'est-à-dire la droite $y = \theta_1x + \theta_0$ qui minimise le critère suivant :
# $$
# \frac 1 m \sum \left( \theta_0 + \theta_1 x_i - y_i\right)^2.
# $$
#
# Autrement dit, on cherche à minimiser la moyenne des distances verticales entre chaque point du nuage et la droite. <br>
# Utilisez une descente de gradient (en 2D) pour trouver les caractéristiques $\theta_0$ et $\theta_1$ de la droite de régression linéaire correspondant à un nuage de points. Pour générer un nuage de point, vous pouvez utiliser le code suivant :

# %%
from random import random
m = 40
sizeNoise = 10
x = [random()*50 + 5 for i in range(m)]
noise = [random() * sizeNoise for i in range(m)] # ou np.rand(m,1) * sizeNoise
pente = 0.8
b =  20
y = [b + pente*x[i] + noise[i] for i in range(m)] 

plt.plot(x,y,'bx')
# Out:
# 2023-09-21 11:52:49.057 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.071 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.084 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.098 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.111 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.125 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.139 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.153 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.182 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.196 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.211 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.226 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.241 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.258 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.272 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.287 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.301 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.316 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.330 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.344 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.357 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.371 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.384 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.397 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.411 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.435 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.448 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.461 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.474 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.487 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.500 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.514 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.527 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.541 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.554 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.568 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.582 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.596 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.609 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.624 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.638 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.653 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.667 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.681 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.696 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.710 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.725 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.740 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.755 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.769 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.784 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.800 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.814 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.829 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.844 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.859 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.873 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.888 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.901 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.916 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.930 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.944 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.959 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.974 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:49.989 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.003 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.018 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.033 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.048 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.063 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.078 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.093 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.108 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.122 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.137 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.152 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.169 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.182 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.197 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.210 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.224 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.237 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.249 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.261 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.274 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.287 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.299 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.311 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.324 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.337 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.349 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.361 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.375 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.387 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.399 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.412 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.425 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.438 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.450 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.462 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.475 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.488 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.500 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.513 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.526 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.539 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.551 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.564 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.577 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.590 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.602 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.616 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.628 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.642 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.655 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.669 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.683 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.697 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.711 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.726 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.740 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.755 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.770 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.784 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.799 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.814 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.828 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.843 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.857 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.872 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.886 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.899 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.914 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.928 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.943 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.957 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.972 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.986 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:50.999 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.014 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.028 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.042 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.056 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.070 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.084 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.098 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.112 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.127 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.141 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.156 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.170 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.184 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.198 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.211 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.224 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.238 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.252 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.266 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.281 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.296 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.309 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.322 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.336 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.351 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.365 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.381 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.395 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.408 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.423 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.439 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.452 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.467 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.481 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.496 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.511 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.526 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.540 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.554 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.569 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.583 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.597 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.617 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.632 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.645 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.659 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.674 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.688 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.703 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.716 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.731 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.746 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.761 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.776 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.791 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.805 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.821 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.836 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.850 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.865 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.880 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.894 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.909 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.925 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.940 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.954 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.969 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.983 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:51.998 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.012 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.027 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.041 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.057 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.070 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.086 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.101 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.115 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.131 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.146 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.161 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.175 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.190 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.204 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.219 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.234 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.249 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.264 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.279 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.293 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.308 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.323 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.337 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.352 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.366 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.380 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.395 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.410 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.424 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.439 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.455 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.469 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.484 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.499 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.514 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.529 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.543 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.558 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.572 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.587 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.602 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.616 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.631 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:52:52.645 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# ...
# 2023-09-21 11:53:02.375 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.393 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.408 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.424 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.439 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.455 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.471 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.486 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.501 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.516 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.531 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.545 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.560 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.574 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.590 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.605 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.619 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.635 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.652 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.667 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.682 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.697 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.711 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.726 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.742 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.757 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.771 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.786 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.801 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.815 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.830 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.844 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.860 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.874 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.890 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.905 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.921 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.936 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.951 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.968 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.984 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:02.999 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.015 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.030 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.046 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.061 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.078 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.094 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.108 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.123 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.137 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.152 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.167 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.182 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.197 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.213 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.228 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.243 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.260 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.275 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.293 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.307 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.323 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.338 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.354 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.369 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.385 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.401 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.417 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.434 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.451 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.467 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.483 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.498 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.514 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.531 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.547 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.564 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.581 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.599 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.614 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.628 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.644 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-09-21 11:53:03.659 python[16303:107005] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
